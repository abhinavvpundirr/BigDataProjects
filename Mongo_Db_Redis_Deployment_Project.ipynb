# %% [markdown]
# # <span style="font-size:35px;color:#3665af">Section 1: MongoDB </span>
#
# <hr>
# In this section, we will practice how to use MongoDB. <br>
#
# ## Pre-reqs:
#
# You need to have your environment set up on Google Cloud working. Please refer to the provided Google Cloud instructions for this setup. <br>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">1. Environment Setup </div>
#
# <br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.1. Uploading your files to the cloud </div>
#
# We need to upload the file cities.txt to the bucket. In the following procedure we will refer to the bucket name as **bigdatasystem\_1234\_bucket** so you need to replace that with your bucket name.
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.2. Creating and uploading a Bucket </div>
#
# 1. Go to the cloud console.
# 2. Using the menu select Cloud Storage and then select your bucket. If you don't have one, you need to create one.
# 3. Drag your file to the bucket.
#
#
# ![Console](img/Storage.png)

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.3. Configuring a MongoDB Instance</div>
#
# Google cloud provides two ways to deploy a MongoDB instance. The first way is by creating a MongoDB Cluster. For this lab that option is too costly. The second one is by deploying a container. We will implement this latter approach.
#
# To do that, first open the Google Cloud console. Go to the web console and select your project, then click on the console icon on the top right corner.
#
# ![Console launcher](img/console.png)
#
# __ After you open your console, you should have something like this: __
# <hr>
#
# ![Console](img/console2.png)
#
# <br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.4. Pulling Docker image</div>
#
# To pull the docker image just type and run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# gcloud docker -- pull launcher.gcr.io/google/mongodb3:latest
# </pre>
#
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.5. Creating the necessary directories</div>
#
# Just run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# mkdir -p ~/mongo/data/shard1
# mkdir -p ~/mongo/files
# </pre>
#
# We need to pull the _cities.txt_ file from the bucket to the console.
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# gsutil cp gs://bigdatasystem_1234_bucket/cities.txt ~/mongo/files/cities.txt
# </pre>
#
# <div class="alert alert-block alert-info">
# <b>NOTE:</b> Remember to use your bucket name
# </div>

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.6. Running docker</div>
#
# To create a MongoDB instance just run this command.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker run \
#   --name server1 \
#   -p 27017:27017 \
#   -v ~/mongo/data/shard1:/data/db \
#   -v ~/mongo/files:/files \
#   -d \
#   launcher.gcr.io/google/mongodb3
# </pre>
#
# - --name sets the name of the docker container
# - -p sets the port for MongoDB, in this case 27017
# - -v maps a host directory to the container; e.g. maps the ~/mongo/data/shard1 to the /data/db in the container
# - -d indicates the process to run in the container
#
#
# **Once you run this command, you should get an hexadecimal id of the image**.<br><br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.7. Docker Reference:</div>
#
# [Reference](https://docs.docker.com/) and [Cheat Sheet](https://github.com/wsargent/docker-cheat-sheet)
#
# #### To check which are the dockers containers currently executing
# Run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker ps
# </pre>
#
# #### To stop a docker container
# Run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker stop \<dockerName\>
# </pre>
# Example:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker stop server1
# </pre>
#
# #### To remove (destroy) a docker container
# Run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker rm \<dockerName\>
# </pre>
# Example:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker rm server1
# </pre>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">2. Connecting to MongoDB </div>
#
#
# To execute the client run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker exec -it server1 mongo admin
# </pre>
#
# You should get the following output:
#
# ![mongo client](img/mongoClient.png)
#
# To end the client just run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# quit();
# </pre>

# %% [markdown]
# - Create the database **mydb** and the collection **cities**:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# #Create the DB if not exists
# use mydb
# #Creates the collection.
# db.createCollection("cities")
# </pre>
#
# - Verify the existence of the database (mydb) and the database collection (cities):
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# show dbs
# show collections
# </pre>

# %% [markdown]
# <span style="color:RED">Paste the output of the previous four commands here. </span>

# %% [raw]
# 1)Output of docor execution:-
# abhinavvpundirr@cloudshell:~$ docker exec -it server1 mongo admin
# MongoDB shell version v3.6.23
# connecting to: mongodb://127.0.0.1:27017/admin?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("1377b1a6-055c-4fbe-b50f-4ce0f92fe478") }
# MongoDB server version: 3.6.23
# Welcome to the MongoDB shell.
# For interactive help, type "help".
# For more comprehensive documentation, see
#         http://docs.mongodb.org/
# Questions? Try the support group
#         http://groups.google.com/group/mongodb-user
# Server has startup warnings:
# 2023-03-01T00:54:11.134+0000 I STORAGE  [initandlisten]
# 2023-03-01T00:54:11.134+0000 I STORAGE  [initandlisten] ** WARNING: Using the XFS filesystem is strongly recommended with the WiredTiger storage engine
# 2023-03-01T00:54:11.134+0000 I STORAGE  [initandlisten] **          See http://dochub.mongodb.org/core/prodnotes-filesystem
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten]
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] ** WARNING: Access control is not enabled for the database.
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] **          Read and write access to data and configuration is unrestricted.
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten]
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] ** WARNING: This server is bound to localhost.
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] **          Remote systems will be unable to connect to this server.
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] **          Start the server with --bind_ip <address> to specify which IP
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] **          addresses it should serve responses from, or with --bind_ip_all to
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] **          bind to all interfaces. If this behavior is desired, start the
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten] **          server with --bind_ip 127.0.0.1 to disable this warning.
# 2023-03-01T00:54:11.849+0000 I CONTROL  [initandlisten]
# >
#
# 2) Output of Create the database mydb and the collection cities:-
# > use mydb
# switched to db mydb
# > db.createCollection("cities")
# { "ok" : 1 }
#
# 3)Output of verifing the existence of the database (mydb) :-
# > show dbs
# admin   0.000GB
# config  0.000GB
# local   0.000GB
# mydb    0.002GB
#
# 4)Output of database collection (cities):-
# > show collections
# cities

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">2.1. Load some data</div>
#
#
# Quit the client so we can use the mongoimport to load data.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# quit();
# </pre>
#
# - First let's check that we have the file in the correct directory.
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# ls -al ~/mongo/files
# </pre>
# Should list the cities.txt

# %% [markdown]
# - We will use the **mongoimport** tool to load documents from a text file. The syntax is:
# <pre style="background-color:#dddddd;padding:5px;">
# mongoimport  --db <database> --collection <collection> --file <filepath/filename>
# </pre>
#
# - So, to execute it through docker just run:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# docker exec -it server1 mongoimport  --db mydb --collection cities --file /files/cities.txt
# </pre>

# %% [markdown]
# <span style="color:RED">Paste the output here. </span>

# %% [raw]
# abhinavvpundirr@cloudshell:~$ docker exec -it server1 mongoimport  --db mydb --collection cities --file /files/cities.txt
# 2023-03-01T01:10:41.130+0000    connected to: localhost
# 2023-03-01T01:10:41.549+0000    imported 29353 documents

# %% [markdown]
# ### Question 1:
# In English describe the content of the database collection. Also, test the following command:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# db.cities.find().pretty()
# </pre>
#
# <span style="color:RED">Include a sample of the result and your description of what that command does below.</span>

# %% [raw]
# After running the above command , here is the sample of my result :-
# > db.cities.find().pretty()
# {
#         "_id" : "01001",
#         "city" : "AGAWAM",
#         "loc" : [
#                 -72.622739,
#                 42.070206
#         ],
#         "pop" : 15338,
#         "state" : "MA"
# }
# {
#         "_id" : "01002",
#         "city" : "CUSHMAN",
#         "loc" : [
#                 -72.51565,
#                 42.377017
#         ],
#         "pop" : 36963,
#         "state" : "MA"
# }
# etc.
#
# If we just execute the command without the pretty keyword, the sample output would be :-
# > db.cities.find()
# { "_id" : "01001", "city" : "AGAWAM", "loc" : [ -72.622739, 42.070206 ], "pop" : 15338, "state" : "MA" }
# { "_id" : "01002", "city" : "CUSHMAN", "loc" : [ -72.51565, 42.377017 ], "pop" : 36963, "state" : "MA" }
#
# As the above two outputs show , .pretty() function at the end makes the output more readable and in simplified format. It basically displays them in more prettier format as the name of the function suggests.

# %% [markdown]
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>
#
# ##### Using what you learned in class and [MongoDB Reference]( https://www.mongodb.com/docs/v4.4/reference/mongo-shell/ ) answer the following queries using the cities collection.
#
# <hr style="border-top: 1px solid red; margin-top: 20px; margin-bottom: 1px"></hr>

# %% [markdown]
# ### Question 2:
# List all the cities of the State of Colorado.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
To list cities of state of colorado, we can use the below code :-
    > db.cities.find({state:'CO'}).pretty()
    
Sample Output:-
{
        "_id" : "80002",
        "city" : "ARVADA",
        "loc" : [
                -105.098402,
                39.794533
        ],
        "pop" : 12065,
        "state" : "CO"
}
{
        "_id" : "80004",
        "city" : "ARVADA",
        "loc" : [
                -105.11771,
                39.814066
        ],
        "pop" : 33260,
        "state" : "CO"
}
{
        "_id" : "80005",
        "city" : "ARVADA",
        "loc" : [
                -105.109719,
                39.842189
        ],
        "pop" : 22613,
        "state" : "CO"
}
{
        "_id" : "80010",
        "city" : "AURORA",
        "loc" : [
                -104.864618,
                39.736788
        ],
        "pop" : 27090,
        "state" : "CO"
}
{
        "_id" : "80011",
        "city" : "AURORA",
        "loc" : [
                -104.815233,
                39.737809
        ],
        "pop" : 36021,
        "state" : "CO"
}

To just list down the cities and not include the other collection columns , we can use code :-
    > db.cities.find({ state: "CO" }, { city: 1,_id:0}).pretty()
Sample Output:-
{ "city" : "ARVADA" }
{ "city" : "ARVADA" }
{ "city" : "ARVADA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "ARVADA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "AURORA" }
{ "city" : "BROOMFIELD" }
{ "city" : "WESTMINSTER" }
{ "city" : "COMMERCE CITY" }
{ "city" : "LOUISVILLE" }
{ "city" : "LAFAYETTE" }
{ "city" : "WHEAT RIDGE" }

# %% [markdown]
# ### Question 3:
# List the first 10 cities of the State of Colorado.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
 To list the first 10 cities of state of colorado:-
        >db.cities.find({ state: "CO" }).pretty().limit(10)
Result:-
    {
        "_id" : "80002",
        "city" : "ARVADA",
        "loc" : [
                -105.098402,
                39.794533
        ],
        "pop" : 12065,
        "state" : "CO"
}
{
        "_id" : "80004",
        "city" : "ARVADA",
        "loc" : [
                -105.11771,
                39.814066
        ],
        "pop" : 33260,
        "state" : "CO"
}
{
        "_id" : "80005",
        "city" : "ARVADA",
        "loc" : [
                -105.109719,
                39.842189
        ],
        "pop" : 22613,
        "state" : "CO"
}
{
        "_id" : "80010",
        "city" : "AURORA",
        "loc" : [
                -104.864618,
                39.736788
        ],
        "pop" : 27090,
        "state" : "CO"
}
{
        "_id" : "80011",
        "city" : "AURORA",
        "loc" : [
                -104.815233,
                39.737809
        ],
        "pop" : 36021,
        "state" : "CO"
}
{
        "_id" : "80012",
        "city" : "AURORA",
        "loc" : [
                -104.837693,
                39.698672
        ],
        "pop" : 37711,
        "state" : "CO"
}
{
        "_id" : "80013",
        "city" : "AURORA",
        "loc" : [
                -104.784566,
                39.657457
        ],
        "pop" : 45335,
        "state" : "CO"
}
{
        "_id" : "80003",
        "city" : "ARVADA",
        "loc" : [
                -105.065549,
                39.828572
        ],
        "pop" : 32980,
        "state" : "CO"
}
{
        "_id" : "80016",
        "city" : "AURORA",
        "loc" : [
                -104.741734,
                39.618713
        ],
        "pop" : 4085,
        "state" : "CO"
}
{
        "_id" : "80017",
        "city" : "AURORA",
        "loc" : [
                -104.788093,
                39.694827
        ],
        "pop" : 25910,
        "state" : "CO"
}

# %% [markdown]
# ### Question 4:
# List the 10 cities of the State of Colorado with largest populations.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
Top ten cities with largest populations can be derived by below code :-
> db.cities.find({ state: "CO" }).sort({ pop: -1 }).limit(10)

Result:-
{ "_id" : "80123", "city" : "BOW MAR", "loc" : [ -105.07766, 39.596854 ], "pop" : 59418, "state" : "CO" }
{ "_id" : "80221", "city" : "FEDERAL HEIGHTS", "loc" : [ -105.007985, 39.840562 ], "pop" : 54069, "state" : "CO" }
{ "_id" : "80631", "city" : "GARDEN CITY", "loc" : [ -104.704756, 40.413968 ], "pop" : 53905, "state" : "CO" }
{ "_id" : "80219", "city" : "DENVER", "loc" : [ -105.034134, 39.695624 ], "pop" : 48234, "state" : "CO" }
{ "_id" : "80501", "city" : "LONGMONT", "loc" : [ -105.10095, 40.177921 ], "pop" : 47166, "state" : "CO" }
{ "_id" : "80013", "city" : "AURORA", "loc" : [ -104.784566, 39.657457 ], "pop" : 45335, "state" : "CO" }
{ "_id" : "80030", "city" : "WESTMINSTER", "loc" : [ -105.037086, 39.854238 ], "pop" : 43235, "state" : "CO" }
{ "_id" : "80110", "city" : "CHERRY HILLS VIL", "loc" : [ -104.990022, 39.646027 ], "pop" : 40226, "state" : "CO" }
{ "_id" : "80303", "city" : "BOULDER", "loc" : [ -105.239178, 39.991381 ], "pop" : 39860, "state" : "CO" }
{ "_id" : "80906", "city" : "COLORADO SPRINGS", "loc" : [ -104.819893, 38.790164 ], "pop" : 38856, "state" : "CO" }

# %% [markdown]
# ### Question 5:
# List the 10 cities with largest populations.
#
# <span style="color:RED">Place your code and a sample of the result here.</span>

# %%
Top ten cities with largest populations can be derived by below code:-
    > db.cities.find().sort({ pop: -1 }).limit(10)
Result:-
{ "_id" : "60623", "city" : "CHICAGO", "loc" : [ -87.7157, 41.849015 ], "pop" : 112047, "state" : "IL" }
{ "_id" : "11226", "city" : "BROOKLYN", "loc" : [ -73.956985, 40.646694 ], "pop" : 111396, "state" : "NY" }
{ "_id" : "10021", "city" : "NEW YORK", "loc" : [ -73.958805, 40.768476 ], "pop" : 106564, "state" : "NY" }
{ "_id" : "10025", "city" : "NEW YORK", "loc" : [ -73.968312, 40.797466 ], "pop" : 100027, "state" : "NY" }
{ "_id" : "90201", "city" : "BELL GARDENS", "loc" : [ -118.17205, 33.969177 ], "pop" : 99568, "state" : "CA" }
{ "_id" : "60617", "city" : "CHICAGO", "loc" : [ -87.556012, 41.725743 ], "pop" : 98612, "state" : "IL" }
{ "_id" : "90011", "city" : "LOS ANGELES", "loc" : [ -118.258189, 34.007856 ], "pop" : 96074, "state" : "CA" }
{ "_id" : "60647", "city" : "CHICAGO", "loc" : [ -87.704322, 41.920903 ], "pop" : 95971, "state" : "IL" }
{ "_id" : "60628", "city" : "CHICAGO", "loc" : [ -87.624277, 41.693443 ], "pop" : 94317, "state" : "IL" }
{ "_id" : "90650", "city" : "NORWALK", "loc" : [ -118.081767, 33.90564 ], "pop" : 94188, "state" : "CA" }

# %% [markdown]
# <hr style="border: 1px double blue;" >
#
# ## Map-Reduce with MongoDB
#
# We can run map-reduce jobs on Mongodb. Let's count the number of cities per state:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# db.cities.mapReduce(
#                     function()           { emit(this.state,1); },
#                     function(key,values) {return key,Array.sum(values);},
#                     { out: "citiesPerState" }
#                    )
# </pre>
#
# This code will generate a new collection instead of displaying the result.
# Use the commands discussed before to list the collections and to get the information from the new collection.

# %% [markdown]
# ### Question 6:
# <span style="color:RED">Place your code output (map-reduce) here.</span>

# %% [raw]
# Output of map-reduce:-
#
# {
#         "result" : "citiesPerState",
#         "timeMillis" : 197,
#         "counts" : {
#                 "input" : 29353,
#                 "emit" : 29353,
#                 "reduce" : 350,
#                 "output" : 51
#         },
#         "ok" : 1
# }

# %% [markdown]
# ### Question 7:
# <span style="color:RED">Place the list of collections here.</span>

# %% [raw]
# Code:-
# > show collections
# Result:-
# cities
# citiesPerState

# %% [markdown]
# ### Question 8:
# <span style="color:RED">Place the content of the new collection here.</span>

# %% [raw]
# Code:-
# > db.citiesPerState.find().pretty()
# Result:-
# { "_id" : "AK", "value" : 195 }
# { "_id" : "AL", "value" : 567 }
# { "_id" : "AR", "value" : 578 }
# { "_id" : "AZ", "value" : 270 }
# { "_id" : "CA", "value" : 1516 }
# { "_id" : "CO", "value" : 414 }
# { "_id" : "CT", "value" : 263 }
# { "_id" : "DC", "value" : 24 }
# { "_id" : "DE", "value" : 53 }
# { "_id" : "FL", "value" : 804 }
# { "_id" : "GA", "value" : 635 }
# { "_id" : "HI", "value" : 80 }
# { "_id" : "IA", "value" : 922 }
# { "_id" : "ID", "value" : 244 }
# { "_id" : "IL", "value" : 1237 }
# { "_id" : "IN", "value" : 676 }
# { "_id" : "KS", "value" : 715 }
# { "_id" : "KY", "value" : 809 }
# { "_id" : "LA", "value" : 464 }
# { "_id" : "MA", "value" : 474 }

# %% [markdown]
# ### Map-Reduce - Question 9:
# Generate a collection called **populationPerState** that contains the population of each state.
#
# <span style="color:RED">Place your code, code output and a sample of the result here.</span>

# %% [raw]
# The code :-
# > db.cities.mapReduce(
# ...                      function()           { emit(this.state,this.pop); },
# ...                      function(key,values) {return key,Array.sum(values);},
# ...                      { out: "populationPerStates" }
# ...                 )
#
# Code Output:-
# {
#         "result" : "populationPerState",
#         "timeMillis" : 240,
#         "counts" : {
#                 "input" : 29353,
#                 "emit" : 29353,
#                 "reduce" : 350,
#                 "output" : 51
#         },
#         "ok" : 1
# }
# Result Sample:-
# > db.populationPerState.find().pretty()
# { "_id" : "AK", "value" : 544698 }
# { "_id" : "AL", "value" : 4040587 }
# { "_id" : "AR", "value" : 2350725 }
# { "_id" : "AZ", "value" : 3665228 }
# { "_id" : "CA", "value" : 29754890 }
# { "_id" : "CO", "value" : 3293755 }
# { "_id" : "CT", "value" : 3287116 }
# { "_id" : "DC", "value" : 606900 }
# { "_id" : "DE", "value" : 666168 }
# { "_id" : "FL", "value" : 12686644 }
# { "_id" : "GA", "value" : 6478216 }
# { "_id" : "HI", "value" : 1108229 }
# { "_id" : "IA", "value" : 2776420 }
# { "_id" : "ID", "value" : 1006749 }
# { "_id" : "IL", "value" : 11427576 }
# { "_id" : "IN", "value" : 5544136 }
# { "_id" : "KS", "value" : 2475285 }
# { "_id" : "KY", "value" : 3675484 }
# { "_id" : "LA", "value" : 4217595 }
# { "_id" : "MA", "value" : 6016425 }

# %% [markdown]
# ### Map-Reduce - Question 10:
# Generate a collection called **totalPopulation** that contains the entire population of the USA.

# %% [markdown]
# <span style="color:RED">Place your code, code output and a sample of the result here.</span>
# > Hint: you can use your previous computed collection.

# %% [raw]
# Code:-
# db.populationPerState.mapReduce(
#   function() { emit(null, this.value); },
#   function(key, values) {return key,Array.sum(values);},
#   {
#     out: "totalPopulation",
#     scope: {
#       USA: "United States"
#     },
#     finalize: function(key, pop) {
#       if (key === null) {
#         return {
#           totalPopulation: pop,
#           country: this.USA
#         };
#       }
#     }
#   }
# )
#
# Code Output:-
# {
#         "result" : "totalPopulation",
#         "timeMillis" : 61,
#         "counts" : {
#                 "input" : 51,
#                 "emit" : 51,
#                 "reduce" : 1,
#                 "output" : 1
#         },
#         "ok" : 1
# }
#
# Sample Result:-
# > db.totalPopulation.find().pretty()
# {
#         "_id" : null,
#         "value" : {
#                 "totalPopulation" : 248408400,
#                 "country" : "United States"
#         }
# }

# %% [markdown]
# <span style="text-align:center;font-size:30px;color:#2F632A">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;STOP AND DELETE YOUR DOCKER WHEN YOU ARE FINISHED
# </span>
# <br>

# %% [markdown]
# <hr style="border-top: 5px solid purple; margin-top: 1px; margin-bottom: 1px"></hr>

# %% [markdown]
# # <span style="font-size:35px;color:#3665af">Section 2: REDIS </span>
# <hr>
#
# The objective of this part of the assignment is to introduce the use of REDIS (an in-memory data store) to collect data from various sources for subsequent data processing.
#
# For this assignment, we will be using REDIS on Google Cloud and Twitter Python libraries.
#
# <b><u>Notebook Layout (Table of contents):</u></b>
# 1. Environment Set-up
#    - Deployment a REDIS Cluster
#    - Network Configuration
#    - Enabling Remote Access
#    - Installing Python libraries
# 2. Getting Familiar with REDIS
# 3. Retrieving Information From Twitter
#    - Creating Twitter Credentials
#    - Accessing Twitter
#    - Saving Tweets to REDIS
#    - Retrieving Tweets from REDIS
# 4. Load Database From CSV

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">1. Environment Setup </div>
#
# For this assignment we will be using the REDIS deployment on Google Cloud. Please follow the instructions to set up the cluster. You can opt to install REDIS on your own system. We don't recommend this approach though.<br><br>
#
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.1. Deployment of a REDIS Cluster </div>
#
# Use the search box, and search REDIS (Google Click to Deploy).
#
# <img src="img/redis_launcher.png" style="width:1000px;">
#
# We will deploy a REDIS cluster using three small-cpu nodes:
# - **Name**: redis-1
# - **Zone**: us-central1-f
# - **Instance Count**: 3
# - **Machine Type**: e2-small (2Gb memory)
# - **Boot Disk size**: 50GB
#
# All other parameters are set to default values. The cost of this deployment is the same as that of any other Virtual Machine (VM) created on the cloud. Your deployment configuration should be similar to this:<br>
#
# <img src="img/redis_deployment.png" style="width:1000px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">1.2. Network Configuration </div>
#
# Once you have your cluster deployed, we need to setup a firewall rule to allow us access from our Jupyter-Notebook. To do that, go to the menu, and select **VPC Network**. Then select Firewall Rules and create a new rule as depicted below:
#
# <img src="img/vpc_network.png" style="width:1000px;">

# %% [markdown]
# <img src="img/fire_rule2.png" style="width:1000px;">

# %% [markdown]
# <img src="img/fire_rule2.png" style="width:1000px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     1.3. Enabling Remote Access to REDIS
# </div>
#
# After creating the firewall rule, we also need to configure REDIS to allow access from the external network. Follow this procedure to accomplish that:
#
# - Select the Compute Engine in the navigation menu
# - Open the SSH terminal to the main server, by selecting SSH on the _redis-1-db-vm-0_ VM (the Compute Engine menu on the Cloud).
#
# <img src="img/redis_vm.png" style="width:550px;">
#
# - Disable the REDIS password:
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# sudo nano /etc/redis/redis.conf
# </pre>
#
# Use your arrow keys to scroll down to the line beginning with "requirepass", then comment that line out using "#".
#
# Press ctrl+x, then hit y, then Enter.
#
# - Restart REDIS
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# sudo service redis-server restart
# </pre>
#
# - Launch the REDIS Client on the console
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# redis-cli
# </pre>
#
# - Within the client change the config to disable protected mode
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# CONFIG SET protected-mode no
# </pre>
# You should get an **OK** message. Then type:
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px navy;">
# quit
# </pre>
#
# Once this is completed, we should be able to access REDIS through the public ip we get on the VM list
#
# <img src="img/redis_vm_ip.png" style="width:550px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     1.4. Installing Python Libraries
# </div>
#
# You need to install two libraries for this assignment:
# - REDIS library, and
# - Twitter library.
#
# - Within your notebook environment (click the jupyterhub logo on top left), open a new terminal (New -> Terminal), and run
#
# <pre style="background-color: #ebece4;padding: 10px;border-left: solid 4px orange;">
# pip install tweepy
# pip install redis
# </pre>

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">
#     2. Getting Familiar with <b>REDIS</b>
# </div>
#
# You can read about the REDIS commands [here](https://redis.io/commands).

# %%
##Import the library
import redis

# %%
## Connect to the server
REDIS_SERVER = '35.202.201.207'
REDIS_PORT   = 6379
myRedis = redis.StrictRedis(host=REDIS_SERVER, port=REDIS_PORT, db=0)

# %%
## Dropping Everything we got on REDIS
display(myRedis.flushdb())
display(myRedis.flushall())
# Out:
# True
# True

# %%
print("I'm storing a value on the key 'myKey'")
display(myRedis.set('myKey', 'This is the key value'))
print("I'm reading the value of 'myKey' from REDIS")
display(myRedis.get('myKey'))
# Out:
# I'm storing a value on the key 'myKey'
# True
# I'm reading the value of 'myKey' from REDIS
# b'This is the key value'

# %%
print("I'm storing a List on REDIS")

print("Adding elements to the end of the list")
display(myRedis.rpush('weekdays','Tuesday'))
display(myRedis.rpush('weekdays','Wednesday'))
display(myRedis.rpush('weekdays','Thursday'))
display(myRedis.rpush('weekdays','Friday'))
print("Current List Length:", myRedis.llen('weekdays'))
display("Current Weekdays Content:",myRedis.lrange('weekdays',0,-1))


print("Adding elements to the beginning of the list")
display(myRedis.lpush('weekdays','Monday'))

print("Current List Length:", myRedis.llen('weekdays'))
display("Current Weekdays Content:",myRedis.lrange('weekdays',0,-1))
# Out:
# I'm storing a List on REDIS
# Adding elements to the end of the list
# 1
# 2
# 3
# 4
# Current List Length: 4
# 'Current Weekdays Content:'
# [b'Tuesday', b'Wednesday', b'Thursday', b'Friday']
# Adding elements to the beginning of the list
# 5
# Current List Length: 5
# 'Current Weekdays Content:'
# [b'Monday', b'Tuesday', b'Wednesday', b'Thursday', b'Friday']

# %%
print("I'm storing a HASH on REDIS")
print("- Remember that hashes can be used to store documents!")

#create a dictionary
user = {"Name"    :"myName", 
        "Company" :"myCompany", 
        "Address" :"myAddress", 
        "Location":"MyLocation"}

print ("Store to REDIS")
display(myRedis.hmset("userDictionary", user))

print ("Retrieve from REDIS")
display(myRedis.hgetall("userDictionary"))
# Out:
# I'm storing a HASH on REDIS
# - Remember that hashes can be used to store documents!
# Store to REDIS
# /tmp/ipykernel_106/2491477041.py:11: DeprecationWarning: Redis.hmset() is deprecated. Use Redis.hset() instead.
#   display(myRedis.hmset("userDictionary", user))
# True
# Retrieve from REDIS
# {b'Name': b'myName',
#  b'Company': b'myCompany',
#  b'Address': b'myAddress',
#  b'Location': b'MyLocation'}

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">
#     3. Retrieving Information From Twitter</div>
# <br>
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.1. Creating Twitter Credentials
# </div>
#
# In order to be able to access tweets from our application, we need a Tweeter account, consumer keys and access tokens.
#
# To generates these, go to https://apps.twitter.com
# and **Create a New App**. Fill in the form and agree with the terms.
#
# Once that's done, select your app and the tab **Keys and Access Tokens**
#
# <img src="img/twitter.png" style="width:550px;">

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.2. Accessing Twitter
# </div>

# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key    = 'PLACE_YOUR_KEYS'
consumer_secret = 'PLACE_YOUR_KEYS'
access_token    = 'PLACE_YOUR_KEYS'
access_secret   = 'PLACE_YOUR_KEYS'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for tweet in tweepy.Cursor(api.home_timeline).items(2):
    # Process a single tweet

    print(tweet._json.keys())
    print()
    print(tweet._json["id"])
    print(tweet._json["text"])
    print(tweet._json["source"])
    print(tweet._json["lang"])
    print(tweet._json["retweeted"])    
    print(tweet._json["retweet_count"])
    print(tweet._json["favorite_count"])
    print()

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.3. Saving Tweets to REDIS
# </div>

# %%
# Lets save tweets

howManyTweets = 20

for tweet in tweepy.Cursor(api.home_timeline).items(howManyTweets):
    # Process a single tweet
    
    ##Formatting the tweet 
    redisTweet = {
                  "text"           :tweet._json["text"].encode('utf-8'), 
                  "source"         :tweet._json["source"].encode('utf-8'), 
                  "lang"           :tweet._json["lang"].encode('utf-8'), 
                  "source"         :tweet._json["source"].encode('utf-8'), 
                  "retweet_count"  :tweet._json["retweet_count"], 
                  "favorite_count" :tweet._json["favorite_count"]
                 }

    ## Saving the tweet as HASH
    myRedis.hmset(tweet._json["id"], redisTweet)
    #display(tweet._json["id"])
    
    ## Adding the Tweet id to the list of tweets
    myRedis.rpush("tweets",str(tweet._json["id"]))
       
print("Done!")

# %% [markdown]
# <div style="font-size:20px;color:#F1F8FC;background-color:#0095EA;padding:10px;">
#     3.4. Retrieving Tweets from REDIS
# </div>

# %%
for id in myRedis.lrange("tweets",0,99):
    print()
    print("Displaying Tweet with ID:",id)
    print("Text:",myRedis.hmget(id,"text"))
    print("ALL DATA:",myRedis.hgetall(id))
    print("========================================================================")

# %% [markdown]
# <div style="font-size:30px;color:#3665af;background-color:#E9E9F5;padding:10px;">
#     4. Load Database From CSV
# </div>
#
# Unzip "CITES Wildlife Trade Database.zip" to get "comptab_2018-01-29 16_00_comma_separated.csv"
# ### Question 11:
# Load this csv file into REDIS and compute the number of animals per Order for each importer. Your output should be similar to this:
# <br>
#
# US . Carnivora . XXX
# <br>
# US . Falconiformes . XXX
# <br>
# US . Artiodactyla . XXX
# <br>
# ...
# <br>
# AD . Acipenseriformes . XXX
# <br>
# AD . Falconiformes . XXX
# <br>
# AD . Carnivora . XXX
# <br>
# ...
#
# Measure the running time, and present the average running time for the load and the processing operations.
#
# **Please also explain your code**
# <br>
# Hint: You can download CITES Wildlife Trade Database.zip, unzip it and open comptab_2018-01-29 16_00_comma_separated.csv to see the data

# %% [markdown]
# <span style="color:RED">PLACE YOUR ANSWERS/CODE IN CELLS BELOW</span>

# %%
import pandas as pd
import redis
import time

# Connect to Redis
REDIS_SERVER = '35.202.201.207'
REDIS_PORT   = 6379
myRedis = redis.StrictRedis(host=REDIS_SERVER, port=REDIS_PORT, db=0)
df=pd.read_csv('comptab_2018-01-29 16_00_comma_separated.csv')
f=df.groupby(['Importer','Order'])['Importer reported quantity'].mean()
start_time = time.time()
#Loading into Redis
for key, value in f.items():
    hash_field = f"{key[0]}.{key[1]}"
    myRedis.hset("animalsperorder", hash_field, value)
#Retrieving rows from Redis
values=myRedis.hgetall("animalsperorder")
end_time = time.time()
decoded_values = {}
for key, value in values.items():
    decoded_key = key.decode()
    decoded_value = value.decode()
    decoded_values[decoded_key] = f"{decoded_value}"
for key, value in decoded_values.items():
    print(f"{key}.{value}")
elapsed_time_toload = end_time - start_time
print(f"Running time to load and process: {elapsed_time_toload:.2f} seconds")
# Out:
# KY.Liliales.nan
# KE.Serpentes.nan
# NO.Sapindales.nan
# AO.Orchidales.nan
# TH.Galliformes.nan
# CO.Anseriformes.nan
# BH.Myrtales.nan
# YE.Myrtales.nan
# ES.Carnivora.5.823529411764706
# TR.Perissodactyla.1.1666666666666667
# LK.Crocodylia.nan
# JO.Scleractinia.nan
# AE.Gentianales.nan
# GH.Liliales.nan
# LB.Nepenthales.nan
# BG.Proboscidea.2.0
# DZ.Orchidales.nan
# DE.Caudata.20.0
# FR.Pholidota.41.0
# MU.Serpentes.nan
# DZ.Caryophyllales.nan
# ZW.Artiodactyla.6.666666666666667
# ES.Falconiformes.2.2564102564102564
# TN.Ranunculales.nan
# SN.Psittaciformes.nan
# CO.Cyatheales.nan
# KP.Pholidota.nan
# UA.Primulales.nan
# MW.Crocodylia.nan
# CI.Caryophyllales.nan
# AG.Sapindales.nan
# PK.Sapindales.nan
# IL.Nepenthales.nan
# IL.Proboscidea.nan
# SR.Columbiformes.nan
# RE.Euphorbiales.nan
# BA.Serpentes.nan
# SE.Osteoglossiformes.15.0
# XX.Veneroida.nan
# CA.Carcharhiniformes.nan
# BR.Psittaciformes.nan
# SX.Euphorbiales.nan
# ES.Fabales.21.174333333333333
# TW.Passeriformes.nan
# IR.Testudines.nan
# IS.Veneroida.nan
# SG.Rosales.nan
# CH.Laurales.nan
# GG.Serpentes.10.0
# CY.Cycadales.nan
# CA.Scrophulariales.nan
# UG.Crocodylia.2.0
# DO.Cetacea.3.0
# JE.Psittaciformes.nan
# KP.Coraciiformes.nan
# US.Orchidales.61564.72258426966
# CY.Psittaciformes.nan
# IR.Stolonifera.nan
# GE.Sauria.nan
# PE.Stolonifera.nan
# ID.Gruiformes.nan
# SG.Primates.154.28825
# FR.Testudines.297.5776923076923
# HU.Proboscidea.4.666666666666667
# ID.Primates.nan
# CY.Scleractinia.47.607142857142854
# SC.Caryophyllales.nan
# CA.Syngnathiformes.nan
# CL.Osteoglossiformes.nan
# PL.Veneroida.111.25
# QA.Euphorbiales.nan
# TW.Caryophyllales.nan
# TH.Gentianales.nan
# US.Falconiformes.66.81313131313131
# MQ.Orchidales.nan
# AU.Myliobatiformes.nan
# KW.Milleporina.nan
# MA.Liliales.nan
# BE.Anura.142.0
# HK.Scorpiones.405.0
# TR.Rhamnales.nan
# VN.Proboscidea.nan
# PH.Anseriformes.16.0
# US.Violales.20.0
# MK.Artiodactyla.nan
# RS.Artiodactyla.1.6666666666666667
# BY.Carnivora.1.0
# MG.Caryophyllales.nan
# NO.Sauria.48.714285714285715
# MA.Anseriformes.nan
# BS.Orchidales.nan
# HK.Dipsacales.1.0
# SR.Caryophyllales.nan
# BG.Liliales.295218.95
# TM.Artiodactyla.nan
# NZ.Artiodactyla.2.142857142857143
# MZ.Crocodylia.nan
# MY.Passeriformes.400.0
# KW.Osteoglossiformes.nan
# ME.Rosales.nan
# CZ.Carnivora.8.115384615384615
# LB.Cyatheales.nan
# CA.Scleractinia.nan
# GG.Crocodylia.2.0
# UA.Cycadales.nan
# TH.Columbiformes.nan
# GT.Veneroida.nan
# BY.Acipenseriformes.nan
# AT.Strigiformes.1.0
# IN.Cyatheales.nan
# EG.Sauria.nan
# CW.Crocodylia.nan
# GB.Gorgonacea.2.0
# CH.Ranunculales.nan
# NG.Sauria.nan
# MO.Scleractinia.36.5
# ES.Stolonifera.19.0
# JO.Helioporacea.nan
# SR.Orchidales.nan
# PL.Artiodactyla.19.666666666666668
# AE.Lepidoptera.nan
# NO.Fabales.4.0
# FI.Nepenthales.nan
# DE.Struthioniformes.nan
# MY.Testudines.83.15625
# ES.Crocodylia.1534.1842698412697
# PK.Ranunculales.nan
# ES.Euphorbiales.251.27272727272728
# CW.Euphorbiales.nan
# JP.Struthioniformes.2.0
# GB.Helioporacea.31.0
# TW.Pinales.nan
# SY.Psittaciformes.nan
# DK.Carnivora.8.902439024390244
# CA.Dipsacales.nan
# US.Arhynchobdellida.17219.566666666666
# PL.Syngnathiformes.200.0
# BY.Liliales.nan
# UZ.Acipenseriformes.nan
# JP.Cycadales.174.95
# PT.Perissodactyla.1.7142857142857142
# BQ.Euphorbiales.nan
# XX.Orchidales.nan
# AZ.Galliformes.nan
# XX.Columbiformes.nan
# SD.Sauria.nan
# SN.Carnivora.nan
# NL.Osteoglossiformes.160.0
# NZ.Veneroida.259.06
# BM.Rosales.nan
# RE.Nepenthales.nan
# US.Lamniformes.5.3
# PK.Fabales.nan
# DK.Testudines.16.75
# ME.Psittaciformes.nan
# DE.Carnivora.190.05357142857142
# AZ.Gorgonacea.nan
# VE.Fabales.nan
# MD.Carnivora.nan
# GP.Euphorbiales.nan
# GE.Euphorbiales.nan
# MY.Scleractinia.51.23711340206186
# KP.Proboscidea.nan
# FI.Carnivora.190.86666666666667
# AU.Scleractinia.nan
# AR.Testudines.12.5
# JP.Perissodactyla.2.5
# VN.Carnivora.nan
# BN.Proboscidea.nan
# JO.Psittaciformes.nan
# KP.Ciconiiformes.nan
# UA.Serpentes.nan
# CZ.Liliales.8.333333333333334
# CH.Cetacea.nan
# ID.Anseriformes.nan
# TW.Columbiformes.nan
# AU.Orchidales.nan
# EC.Osteoglossiformes.nan
# BL.Cycadales.nan
# GE.Caryophyllales.nan
# MO.Crocodylia.126.84466019417475
# EC.Serpentes.nan
# GB.Asterales.30.0
# GL.Strigiformes.nan
# CD.Sauria.nan
# TH.Anseriformes.nan
# ET.Serpentes.nan
# MG.Testudines.81.66666666666667
# AG.Cycadales.nan
# JE.Testudines.1.0
# OM.Columbiformes.6.0
# AD.Acipenseriformes.nan
# KP.Psittaciformes.nan
# CH.Passeriformes.nan
# FI.Primates.778.74
# OM.Cycadales.2091.0
# BE.Serpentes.181.83333333333334
# IT.Primates.22774.428571428572
# NL.Crocodylia.138.27272727272728
# CA.Sphenisciformes.nan
# US.Araneae.251.29166666666666
# RU.Strigiformes.nan
# MY.Serpentes.106.3135593220339
# EG.Rosales.nan
# GH.Psittaciformes.nan
# KY.Cyatheales.nan
# EG.Cetacea.nan
# DK.Osteoglossiformes.6.75
# VN.Passeriformes.nan
# AM.Crocodylia.nan
# JO.Nepenthales.nan
# FI.Artiodactyla.1.5714285714285714
# CA.Falconiformes.nan
# AE.Serpentes.172.72727272727272
# FI.Crocodylia.202.5
# PT.Strigiformes.1.0
# DE.Acipenseriformes.11987.817747179486
# ID.Asterales.nan
# GB.Arales.120.5
# PE.Proboscidea.21.333333333333332
# FR.Myrtales.1158.233096173913
# TT.Orchidales.nan
# NL.Veneroida.327.4
# DO.Carcharhiniformes.nan
# GH.Rosales.nan
# GB.Ciconiiformes.nan
# TN.Psittaciformes.nan
# AE.Veneroida.21.0
# PH.Columbiformes.8.0
# KE.Perissodactyla.42.333333333333336
# PL.Crocodylia.86.0
# BE.Euphorbiales.912.5
# DE.Chiroptera.515.5
# GF.Orchidales.nan
# TG.Artiodactyla.nan
# CA.Artiodactyla.nan
# MD.Nepenthales.nan
# XX.Euphorbiales.nan
# IS.Carnivora.nan
# IQ.Cycadales.nan
# UY.Proboscidea.nan
# NO.Anseriformes.nan
# PE.Helioporacea.nan
# KP.Carnivora.nan
# TR.Passeriformes.150.0
# KR.Acipenseriformes.nan
# ES.Liliales.2876.69375
# TT.Primates.6.0
# GR.Crocodylia.114.35714285714286
# DE.Dicksoniales.2.0
# IL.Asterales.nan
# AN.Psittaciformes.nan
# AL.Artiodactyla.nan
# AE.Anseriformes.8.0
# CA.Apiales.nan
# BH.Cycadales.nan
# TR.Coraciiformes.6.0
# AM.Proboscidea.nan
# NL.Testudines.878.7333333333333
# TH.Psittaciformes.nan
# DK.Sauria.120.66666666666667
# KP.Myrtales.nan
# FR.Scrophulariales.18708.5
# CA.Passeriformes.nan
# AU.Ranunculales.nan
# ZA.Liliales.nan
# UZ.Orchidales.nan
# TZ.Perissodactyla.nan
# BR.Sapindales.nan
# DE.Violales.nan
# KP.Perissodactyla.nan
# US.Coraciiformes.1.0
# TW.Stolonifera.nan
# IT.Caryophyllales.51331.0
# EC.Artiodactyla.nan
# RE.Scleractinia.nan
# KR.Cyatheales.nan
# FR.Violales.nan
# HK.Perissodactyla.3.625
# SK.Carnivora.2.875
# VG.Cetacea.1.4
# TW.Apodiformes.nan
# MY.Asterales.nan
# IT.Anura.nan
# TR.Ranunculales.nan
# BD.Dipsacales.nan
# SE.Orchidales.27570.0
# KW.Artiodactyla.3.0
# IR.Osteoglossiformes.nan
# BA.Rosales.nan
# XX.Piciformes.nan
# IR.Araneae.nan
# MX.Euphorbiales.nan
# US.Carcharhiniformes.2.85
# US.Myrtales.160078.6107142857
# NL.Carnivora.2.125
# KR.Liliales.nan
# FR.Orchidales.1731.2827724230253
# CZ.Caryophyllales.83.0
# PE.Sauria.7559.0
# HK.Anguilliformes.8494.88
# US.Passeriformes.14.5
# AT.Piciformes.2.0
# SR.Testudines.nan
# DE.Laurales.42.5
# MK.Caryophyllales.nan
# DE.Mesogastropoda.nan
# GB.Orchidales.2344.9772727272725
# NL.Ebenales.1.0
# DE.Gorgonacea.213.63250000000002
# TM.Serpentes.nan
# RU.Apiales.nan
# GR.Osteoglossiformes.20.0
# HK.Galliformes.2.142857142857143
# KE.Galliformes.507.2
# CH.Sauria.nan
# TR.Cycadales.nan
# ZA.Carnivora.nan
# AW.Euphorbiales.nan
# BJ.Acipenseriformes.nan
# CL.Artiodactyla.7.285714285714286
# BD.Cuculiformes.nan
# DO.Scleractinia.nan
# HK.Perciformes.284.0
# VN.Coraciiformes.nan
# AL.Carnivora.nan
# SE.Passeriformes.nan
# IN.Scleractinia.nan
# CL.Crocodylia.90.36363636363636
# IT.Rheiformes.60.0
# MD.Crocodylia.nan
# UZ.Serpentes.nan
# PH.Acipenseriformes.nan
# AN.Sauria.nan
# KH.Crocodylia.nan
# CC.Crocodylia.nan
# AW.Liliales.nan
# SM.Veneroida.189.0
# CH.Euphorbiales.nan
# AU.Serpentes.nan
# MY.Artiodactyla.3.1046666666666667
# AR.Liliales.84790.0
# ZA.Helioporacea.nan
# KZ.Nepenthales.nan
# GT.Scleractinia.nan
# RU.Perissodactyla.nan
# KH.Sauria.nan
# ID.Acipenseriformes.nan
# ID.Passeriformes.nan
# MO.Caryophyllales.5.0
# FR.Liliales.2933.3333333333335
# MK.Rosales.30000.0
# TM.Crocodylia.nan
# GG.Testudines.2.0
# ES.Sauria.2566.7
# CH.Anseriformes.nan
# FR.Laurales.205.0
# LB.Acipenseriformes.nan
# AM.Cycadales.nan
# SN.Pholidota.nan
# GE.Carnivora.6.0
# MV.Caryophyllales.nan
# RO.Proboscidea.3.0
# US.Ebenales.1.0
# CA.Milleporina.nan
# SE.Serpentes.30.0
# PA.Psittaciformes.nan
# TD.Crocodylia.nan
# ME.Liliales.nan
# KR.Stolonifera.nan
# UG.Proboscidea.5.0
# KR.Asterales.nan
# TH.Perissodactyla.nan
# OM.Euphorbiales.2850.0
# BD.Piciformes.nan
# MN.Primates.nan
# SI.Artiodactyla.1.0
# ES.Psittaciformes.0.775
# FJ.Rosales.nan
# IN.Orchidales.6922.2027027027025
# OM.Testudines.157.5
# KP.Fabales.nan
# IL.Sauria.nan
# IT.Bromeliales.3250.0
# ZA.Rosales.nan
# SG.Gorgonacea.nan
# GT.Crocodylia.nan
# DK.Gruiformes.nan
# KW.Euphorbiales.89.07692307692308
# MX.Galliformes.nan
# DE.Primates.500.2819078947369
# GP.Caryophyllales.nan
# US.Ranunculales.80479.0
# US.Peramelemorphia.4.0
# KG.Crocodylia.nan
# GI.Primates.nan
# KW.Serpentes.nan
# RU.Euphorbiales.nan
# MG.Psittaciformes.20.0
# OM.Sauria.nan
# GB.Testudines.729.55
# GE.Proboscidea.1.0
# PH.Galliformes.604.535
# EG.Serpentes.nan
# US.Pinales.11.5
# CR.Acipenseriformes.nan
# CH.Perissodactyla.nan
# ZW.Liliales.nan
# CA.Bromeliales.nan
# RU.Gruiformes.nan
# GB.Caudata.12.0
# XV.Falconiformes.nan
# IN.Osteoglossiformes.nan
# DK.Cetacea.89.39166666666667
# TW.Scleractinia.nan
# BE.Lepidoptera.52.0
# SR.Nepenthales.nan
# GR.Psittaciformes.1.75
# IE.Serpentes.nan
# KW.Stylasterina.nan
# SN.Scleractinia.nan
# ID.Testudines.nan
# MY.Galliformes.nan
# MM.Carnivora.1.0
# PG.Proboscidea.nan
# BL.Serpentes.nan
# HK.Apiales.505763.65800000005
# GU.Crocodylia.nan
# VN.Apiales.nan
# AR.Rheiformes.nan
# MC.Cetacea.1.0
# MA.Euphorbiales.nan
# UA.Artiodactyla.nan
# HK.Acipenseriformes.39.07997592592593
# TW.Crocodylia.nan
# MK.Nepenthales.nan
# ES.Myrtales.48.05
# PA.Artiodactyla.nan
# RU.Asterales.nan
# TR.Artiodactyla.4.771428571428571
# MA.Falconiformes.nan
# CU.Testudines.1.0
# JP.Cuculiformes.1.3333333333333333
# CH.Crocodylia.nan
# SU.Crocodylia.nan
# ZA.Orchidales.nan
# TH.Nepenthales.nan
# CH.Fabales.nan
# ID.Carnivora.nan
# MX.Piciformes.nan
# SG.Cyatheales.nan
# BH.Euphorbiales.nan
# AT.Coraciiformes.1.0
# IS.Anura.nan
# MA.Ranunculales.nan
# SE.Milleporina.nan
# DO.Testudines.10.0
# MG.Serpentes.nan
# NL.Cycadales.190168.6930909091
# GE.Cycadales.nan
# UA.Piciformes.nan
# CR.Caryophyllales.nan
# IN.Psittaciformes.1.0
# VN.Osteoglossiformes.nan
# CV.Liliales.nan
# IT.Stolonifera.180.66666666666666
# US.Osteoglossiformes.2937.711935483871
# NZ.Stylasterina.125.0
# ZA.Artiodactyla.nan
# LV.Artiodactyla.nan
# ES.Columbiformes.151.0
# SG.Stylasterina.1.5
# CO.Primates.nan
# KW.Acipenseriformes.nan
# CL.Orchidales.11386.75
# GH.Serpentes.nan
# VG.Artiodactyla.nan
# US.Chiroptera.51.473333333333336
# IQ.Acipenseriformes.nan
# AU.Fabales.nan
# MX.Falconiformes.nan
# KW.Cycadales.307.8285714285715
# PY.Acipenseriformes.nan
# DZ.Cycadales.nan
# MX.Asterales.nan
# OM.Passeriformes.30.0
# BH.Acipenseriformes.nan
# QA.Primates.18.0
# QA.Crocodylia.35.06060606060606
# FJ.Euphorbiales.nan
# KN.Primates.nan
# TD.Artiodactyla.nan
# SA.Artiodactyla.nan
# LC.Crocodylia.nan
# MM.Sphenisciformes.10.0
# BB.Acipenseriformes.106.1
# AZ.Myrtales.nan
# AU.Euphorbiales.nan
# GT.Cuculiformes.nan
# MP.Orchidales.nan
# ZA.Euphorbiales.nan
# NZ.Stolonifera.167.33333333333334
# BN.Liliales.nan
# AD.Anseriformes.nan
# EE.Proboscidea.1.0
# BS.Crocodylia.nan
# MY.Carnivora.6.0
# SE.Stolonifera.21.0
# PK.Caryophyllales.nan
# KW.Crocodylia.2.0
# CN.Anseriformes.20.333333333333332
# CV.Psittaciformes.nan
# CN.Charadriiformes.1.0
# CO.Acipenseriformes.nan
# RO.Caryophyllales.nan
# SG.Liliales.nan
# GR.Orchidales.41260.0
# TW.Gruiformes.nan
# PH.Scleractinia.nan
# SN.Gruiformes.nan
# BA.Cycadales.nan
# ES.Lepidoptera.nan
# JM.Orchidales.nan
# VN.Liliales.nan
# SG.Crocodylia.4396.366336633663
# NZ.Laurales.nan
# MY.Fabales.124.427
# CG.Primates.nan
# JP.Sapindales.153.09742083333333
# IN.Rhamnales.nan
# KP.Scleractinia.nan
# TJ.Orchidales.nan
# SM.Scleractinia.306.86036036036035
# CN.Stylasterina.2.0
# CO.Asterales.nan
# CH.Nepenthales.nan
# RS.Crocodylia.32.526315789473685
# AN.Crocodylia.nan
# CH.Mesogastropoda.nan
# BS.Cetacea.nan
# HK.Psittaciformes.59.516129032258064
# LT.Sauria.nan
# KE.Psittaciformes.2.0
# VE.Serpentes.nan
# MW.Carnivora.14.0
# ZM.Proboscidea.nan
# DE.Rosales.1.0
# GI.Liliales.nan
# SG.Testudines.3432.1
# PT.Proboscidea.2.7142857142857144
# BO.Serpentes.nan
# CZ.Cycadales.2.0
# DK.Syngnathiformes.90.0
# IE.Cetacea.400.0
# UZ.Passeriformes.26.0
# PW.Orchidales.nan
# UG.Sauria.1.0
# PE.Scleractinia.nan
# SV.Primates.nan
# MX.Acipenseriformes.nan
# AE.Ceratodontiformes.nan
# PL.Perissodactyla.3.3333333333333335
# BD.Columbiformes.nan
# GM.Primates.nan
# LR.Serpentes.nan
# PE.Acipenseriformes.nan
# DZ.Stolonifera.nan
# MX.Apodiformes.nan
# NP.Crocodylia.nan
# AR.Psittaciformes.23.647058823529413
# MV.Orchidales.nan
# NO.Cycadales.nan
# IS.Syngnathiformes.nan
# PK.Gentianales.nan
# NO.Artiodactyla.7.785714285714286
# DE.Perciformes.3581.5
# ID.Fabales.nan
# US.Fabales.18870.24
# CZ.Asterales.503.0
# CH.Liliales.nan
# GR.Proboscidea.1.0
# AM.Acipenseriformes.nan
# KP.Falconiformes.nan
# UA.Arhynchobdellida.nan
# UY.Primulales.nan
# MG.Sauria.1195.5
# BJ.Crocodylia.nan
# AE.Cyatheales.nan
# IN.Crocodylia.124.65789473684211
# AE.Anura.12.0
# AM.Nepenthales.nan
# AO.Euphorbiales.nan
# GE.Ciconiiformes.nan
# AU.Osteoglossiformes.nan
# CL.Gorgonacea.nan
# BR.Stolonifera.nan
# AT.Stylasterina.nan
# CA.Cycadales.nan
# GE.Acipenseriformes.6833.202
# GB.Cetacea.38.1
# PK.Helioporacea.nan
# BS.Syngnathiformes.nan
# MO.Primates.nan
# CY.Testudines.1.0
# AT.Nepenthales.nan
# ES.Ericales.125.0
# UA.Strigiformes.nan
# EG.Caryophyllales.nan
# CZ.Piciformes.2.0
# DZ.Milleporina.nan
# IS.Scleractinia.nan
# EE.Perissodactyla.1.0
# RU.Caryophyllales.nan
# GR.Fabales.nan
# SR.Cycadales.nan
# GT.Ciconiiformes.nan
# TH.Violales.nan
# JP.Stylasterina.48.0
# MC.Acipenseriformes.11.307549999999999
# TH.Carnivora.nan
# FI.Serpentes.3.5
# KR.Artiodactyla.nan
# NP.Gruiformes.nan
# CL.Ranunculales.nan
# MC.Serpentes.62.96666666666667
# JO.Gruiformes.nan
# SN.Orchidales.nan
# QA.Gorgonacea.84.0
# GB.Falconiformes.18.083333333333332
# SI.Falconiformes.1.1111111111111112
# KN.Crocodylia.nan
# RE.Cycadales.nan
# RU.Acipenseriformes.nan
# SX.Cycadales.nan
# PH.Piciformes.4.25
# ES.Sapindales.4986.620666666667
# AE.Nepenthales.72.0
# JP.Sauria.445.4777227722772
# KR.Cycadales.nan
# BM.Testudines.nan
# NZ.Proboscidea.12.62520625
# US.Sauria.666.0818899082569
# AO.Caryophyllales.nan
# PT.Primates.204.5
# KZ.Acipenseriformes.110.06660000000001
# US.Gruiformes.266.41700000000003
# RS.Nepenthales.nan
# IL.Primates.nan
# TH.Serpentes.nan
# QA.Psittaciformes.262.24615384615385
# SG.Psittaciformes.81.93577981651376
# MU.Caryophyllales.nan
# UY.Primates.nan
# CI.Acipenseriformes.nan
# SA.Primates.nan
# DZ.Carnivora.nan
# PK.Galliformes.nan
# BA.Euphorbiales.nan
# EC.Sauria.nan
# MT.Liliales.600.0
# IR.Crocodylia.nan
# GB.Proboscidea.22.0
# GF.Liliales.nan
# BE.Myrtales.18.31
# TJ.Caryophyllales.nan
# MG.Proboscidea.nan
# VN.Falconiformes.nan
# CA.Nepenthales.nan
# BN.Primates.nan
# SN.Pristiformes.nan
# IN.Helioporacea.nan
# MX.Artiodactyla.nan
# TN.Falconiformes.nan
# BS.Acipenseriformes.nan
# PK.Myrtales.nan
# CH.Primulales.nan
# BR.Scleractinia.nan
# IE.Ranunculales.nan
# AU.Cetacea.nan
# JO.Caryophyllales.nan
# KW.Strigiformes.nan
# NG.Euphorbiales.nan
# GH.Sauria.nan
# BL.Galliformes.nan
# SM.Syngnathiformes.210.0
# AE.Acipenseriformes.18698.077706666667
# JP.Lamiales.1081.28738
# GA.Serpentes.nan
# DK.Anura.209.8
# MV.Psittaciformes.nan
# ES.Rosales.153878.5
# CN.Stolonifera.10.0
# NL.Stylasterina.nan
# GR.Milleporina.nan
# UY.Acipenseriformes.127.2725
# PH.Falconiformes.2.0
# OM.Primates.20.0
# BG.Serpentes.nan
# BB.Orchidales.nan
# CA.Asterales.nan
# SR.Liliales.nan
# CN.Sirenia.2.0
# KI.Primulales.nan
# KR.Crocodylia.nan
# LY.Serpentes.nan
# PH.Proboscidea.28.5
# EG.Orchidales.nan
# SV.Acipenseriformes.1.651373
# GL.Serpentes.nan
# GY.Proboscidea.nan
# SA.Gruiformes.nan
# GB.Fabales.10.388571428571428
# CO.Apiales.nan
# MX.Perissodactyla.nan
# TW.Apiales.nan
# PF.Liliales.nan
# BY.Caryophyllales.nan
# PL.Ericales.53467.0
# US.Anura.270.50602409638554
# NZ.Apiales.51.0575
# RS.Orchidales.2850.0
# DE.Ranunculales.233.0
# SG.Cuculiformes.3.5
# AF.Cycadales.1500.0
# AN.Acipenseriformes.nan
# US.Sapindales.31751.0625
# JP.Milleporina.88.0
# TH.Acipenseriformes.nan
# KR.Fabales.nan
# TK.Serpentes.nan
# LA.Scleractinia.nan
# AR.Galliformes.nan
# ID.Cyatheales.nan
# PT.Cuculiformes.1.0
# TR.Crocodylia.120.88953333333333
# DE.Liliales.4735.820176470588
# AT.Liliales.5162.5
# IL.Artiodactyla.nan
# UA.Rheiformes.nan
# RU.Rheiformes.nan
# AE.Primates.nan
# MQ.Nepenthales.nan
# AE.Carnivora.11.083333333333334
# KR.Myliobatiformes.nan
# NL.Cyatheales.66.0
# TT.Perissodactyla.1.0
# AT.Ciconiiformes.1.0
# FJ.Carcharhiniformes.nan
# GH.Orchidales.nan
# MA.Helioporacea.nan
# NL.Fabales.3.9033333333333338
# JM.Piciformes.nan
# JO.Passeriformes.nan
# NE.Crocodylia.nan
# SN.Asterales.nan
# RS.Psittaciformes.2.0
# DE.Anura.56.0
# XX.Testudines.nan
# TT.Liliales.nan
# SN.Galliformes.nan
# AM.Orchidales.nan
# VE.Psittaciformes.1.0
# GI.Crocodylia.nan
# AR.Stolonifera.10.0
# QA.Sauria.25.125
# MX.Cetacea.nan
# BG.Crocodylia.25.153846153846153
# MU.Liliales.nan
# CZ.Osteoglossiformes.2.5
# AE.Caryophyllales.275.5217391304348
# MO.Artiodactyla.13.666666666666666
# UA.Sauria.nan
# ES.Stylasterina.10.0
# NO.Liliales.718.0
# BR.Orchidales.nan
# HK.Rhamnales.18.333333333333332
# DO.Sauria.1.0
# RU.Cetacea.nan
# OM.Falconiformes.nan
# EE.Carnivora.2.142857142857143
# CR.Cyatheales.nan
# SG.Rhamnales.nan
# CZ.Euphorbiales.41.44444444444444
# CN.Fagales.65061.226
# TM.Caryophyllales.nan
# CN.Falconiformes.3077.375
# US.Milleporina.33.333333333333336
# TT.Mesogastropoda.36.0
# CA.Anseriformes.nan
# BD.Stolonifera.nan
# QA.Strigiformes.3.0
# JP.Coelacanthiformes.1.0
# WS.Orchidales.nan
# US.Serpentes.467.48301587301586
# GT.Acipenseriformes.nan
# DK.Falconiformes.700.0
# AE.Scleractinia.59.567567567567565
# US.Anguilliformes.52500.0
# CA.Sauria.nan
# CD.Crocodylia.nan
# SE.Carnivora.34.5
# IT.Osteoglossiformes.193.75
# LT.Psittaciformes.1.5714285714285714
# CD.Acipenseriformes.nan
# PH.Stolonifera.nan
# PE.Artiodactyla.174.4375
# AU.Rheiformes.nan
# GP.Cycadales.nan
# JP.Araneae.37.25
# PL.Scleractinia.594.3263157894737
# CW.Psittaciformes.nan
# ZA.Veneroida.nan
# IE.Primates.nan
# IR.Psittaciformes.nan
# MX.Liliales.nan
# MN.Primulales.nan
# SG.Charadriiformes.1.0
# NZ.Piciformes.1.0
# AE.Pinales.nan
# HK.Ciconiiformes.1.0
# MA.Nepenthales.nan
# FR.Arecales.nan
# FR.Artiodactyla.24.516666666666666
# US.Scandentia.9.5
# DE.Piciformes.10.0
# CW.Caryophyllales.nan
# JP.Caryophyllales.7588.855555555556
# KP.Sauria.nan
# MZ.Psittaciformes.nan
# MU.Helioporacea.nan
# AE.Columbiformes.nan
# TT.Artiodactyla.6.0
# CA.Araneae.nan
# SU.Sauria.nan
# LB.Passeriformes.nan
# IS.Proboscidea.nan
# UZ.Carnivora.2.0
# SG.Artiodactyla.309.8643
# FO.Euphorbiales.nan
# SN.Passeriformes.nan
# FO.Cetacea.nan
# US.Scorpiones.505.5
# BH.Testudines.20.0
# CZ.Nepenthales.nan
# MY.Anguilliformes.nan
# VC.Sapindales.nan
# GE.Primulales.nan
# MO.Carnivora.2.0
# RU.Gentianales.nan
# CY.Caryophyllales.nan
# BH.Gorgonacea.nan
# XX.Anguilliformes.nan
# UA.Euphorbiales.nan
# KP.Serpentes.nan
# LB.Helioporacea.nan
# FR.Anseriformes.2.0
# SI.Sauria.131.0
# PH.Serpentes.32.72727272727273
# MK.Carnivora.1.0
# IL.Scleractinia.nan
# NL.Struthioniformes.1.0
# EE.Arhynchobdellida.2000.0
# GL.Proboscidea.nan
# US.Strigiformes.8.272058823529411
# CA.Antipatharia.nan
# JP.Pinales.139.0
# NL.Lepidoptera.nan
# RS.Primates.242.6
# IL.Orchidales.nan
# FR.Perissodactyla.5.166666666666667
# KP.Milleporina.nan
# TW.Psittaciformes.nan
# TN.Primulales.nan
# FJ.Lamniformes.nan
# AW.Caryophyllales.nan
# ZA.Milleporina.nan
# KH.Caryophyllales.nan
# PK.Crocodylia.nan
# AU.Perissodactyla.nan
# GP.Nepenthales.nan
# AD.Serpentes.nan
# IM.Testudines.1.0
# RO.Serpentes.1.0
# TZ.Anura.nan
# SE.Stylasterina.10.0
# CH.Testudines.nan
# EE.Crocodylia.280.0
# DE.Crocodylia.1341.725
# CH.Scleractinia.nan
# AE.Osteoglossiformes.nan
# XX.Arhynchobdellida.nan
# NL.Sauria.111.17307692307692
# CN.Milleporina.6.0
# IT.Galliformes.1351.5
# AE.Ciconiiformes.16.0
# US.Pholidota.55.81818181818182
# NL.Liliales.1495870.5454545454
# JP.Osteoglossiformes.608.03125
# PE.Ciconiiformes.6.0
# NI.Primates.nan
# TW.Gentianales.nan
# CN.Galliformes.1.0
# CN.Carnivora.218.91666666666666
# SK.Primates.4.5
# DK.Psittaciformes.4.0
# AU.Primates.nan
# JP.Primates.1303.5309302325581
# AM.Serpentes.nan
# CN.Anura.nan
# NL.Helioporacea.nan
# BA.Orchidales.nan
# OM.Serpentes.nan
# FR.Araneae.100.0
# SE.Fabales.1.0
# VE.Crocodylia.nan
# SG.Veneroida.205.6
# IT.Ranunculales.nan
# ID.Cuculiformes.nan
# KW.Primates.nan
# US.Myliobatiformes.16.333333333333332
# RU.Scleractinia.nan
# SN.Artiodactyla.nan
# GH.Crocodylia.nan
# UA.Acipenseriformes.nan
# BE.Psittaciformes.1.6666666666666667
# IL.Carnivora.nan
# LT.Perissodactyla.1.0
# LV.Carnivora.4.666666666666667
# TH.Caryophyllales.nan
# SA.Helioporacea.nan
# CH.Caryophyllales.nan
# XX.Cycadales.nan
# SE.Artiodactyla.3.75
# SA.Orchidales.nan
# IT.Stylasterina.nan
# MD.Serpentes.nan
# RO.Struthioniformes.1.0
# PT.Carnivora.1.0
# HK.Caryophyllales.311.46031746031747
# MG.Orchidales.18.0
# VN.Acipenseriformes.nan
# GD.Crocodylia.nan
# MV.Carcharhiniformes.nan
# EG.Apiales.nan
# KG.Acipenseriformes.nan
# IL.Arhynchobdellida.nan
# KR.Milleporina.nan
# UA.Milleporina.nan
# IS.Liliales.nan
# FR.Mesogastropoda.134449.03666666665
# US.Gorgonacea.222.81274193548387
# ES.Asterales.35.0
# GU.Milleporina.nan
# BR.Anseriformes.nan
# AR.Apodiformes.nan
# HU.Testudines.2300.0
# CN.Anguilliformes.nan
# YU.Primates.nan
# OM.Scleractinia.nan
# NL.Milleporina.nan
# MX.Crocodylia.nan
# BE.Perissodactyla.7.166666666666667
# ME.Crocodylia.nan
# CM.Serpentes.nan
# MG.Nepenthales.nan
# MT.Primates.1.0
# CA.Serpentes.nan
# LA.Sauria.nan
# NO.Psittaciformes.9.604651162790697
# BH.Orchidales.nan
# PH.Liliales.nan
# MA.Strigiformes.1.0
# ES.Scleractinia.84.453125
# ES.Serpentes.910.0222222222222
# PY.Sapindales.nan
# KG.Serpentes.nan
# AW.Acipenseriformes.nan
# OM.Orchidales.nan
# GB.Primates.397.219512195122
# SK.Artiodactyla.1.8333333333333333
# PK.Euphorbiales.nan
# LV.Acipenseriformes.4021.0
# VN.Asterales.nan
# RO.Liliales.65.0
# KZ.Cycadales.nan
# BE.Carnivora.3.0217948717948717
# MX.Carnivora.nan
# IQ.Serpentes.nan
# TR.Stylasterina.nan
# GT.Sauria.nan
# US.Sphenisciformes.36.0
# PA.Ciconiiformes.nan
# US.Antipatharia.4.48
# TN.Orchidales.nan
# CH.Rodentia.nan
# NO.Carnivora.4.5
# VN.Galliformes.nan
# US.Veneroida.1273.9
# GB.Scleractinia.560.1063829787234
# IT.Solanales.3398.0
# BR.Fabales.nan
# FR.Galliformes.4.0
# TN.Primates.17.0
# RU.Orchidales.nan
# MY.Syngnathiformes.27.5
# AT.Struthioniformes.3.0
# MU.Sauria.nan
# PK.Anseriformes.nan
# UA.Liliales.nan
# SK.Perissodactyla.7.25
# BH.Nepenthales.nan
# AR.Asterales.nan
# KP.Artiodactyla.nan
# SA.Serpentes.nan
# NZ.Nepenthales.nan
# UG.Apiales.1.0
# DE.Gentianales.873.9
# PT.Sapindales.55.85
# CN.Passeriformes.nan
# AZ.Orchidales.nan
# IN.Nepenthales.nan
# KR.Proboscidea.nan
# IN.Dipsacales.nan
# US.Mesogastropoda.27538.016197183097
# CN.Primates.136.1915625
# AO.Cycadales.nan
# IE.Orchidales.6980.263333333333
# UA.Coraciiformes.nan
# TT.Struthioniformes.18.0
# BQ.Nepenthales.nan
# US.Primates.1048.2802538071066
# IT.Acipenseriformes.69.5506
# MC.Crocodylia.77.50943396226415
# SA.Falconiformes.nan
# GB.Caryophyllales.974.75
# GL.Sauria.nan
# KY.Caryophyllales.nan
# NO.Falconiformes.nan
# KG.Psittaciformes.nan
# GP.Liliales.nan
# HK.Bromeliales.165.0
# CO.Sauria.nan
# AT.Stolonifera.15.0
# AE.Perissodactyla.2.0
# UY.Rosales.nan
# MG.Acipenseriformes.37000.6
# CZ.Galliformes.nan
# IT.Gorgonacea.1703.5786842105263
# ZW.Caryophyllales.nan
# GT.Gruiformes.nan
# ZA.Anseriformes.nan
# IN.Liliales.nan
# BE.Strigiformes.1.0
# GB.Cuculiformes.3.0
# NZ.Scleractinia.296.5128904109589
# CN.Fabales.68357.54287755102
# SR.Passeriformes.nan
# AM.Sauria.nan
# HK.Strigiformes.1.0
# US.Nepenthales.13524.724137931034
# EG.Liliales.nan
# JP.Falconiformes.7.911764705882353
# TW.Gorgonacea.nan
# AT.Serpentes.7.5
# ME.Nepenthales.nan
# MC.Liliales.4032.0
# CN.Scleractinia.440.08760330578514
# ME.Caryophyllales.nan
# TR.Osteoglossiformes.17.0
# JP.Testudines.174.22666666666666
# CN.Lepidoptera.57.8
# FO.Orchidales.nan
# CM.Crocodylia.nan
# ES.Cetacea.32.5
# AT.Fabales.nan
# CY.Nepenthales.nan
# YU.Crocodylia.nan
# SG.Orchidales.154.6
# AR.Cuculiformes.nan
# AE.Psittaciformes.31.767441860465116
# DE.Sphenisciformes.7.5
# SG.Perciformes.1.0
# EC.Crocodylia.nan
# PL.Galliformes.104.0
# FR.Chiroptera.230.0
# FJ.Crocodylia.nan
# NZ.Osteoglossiformes.34.0
# ES.Piciformes.4.0
# DE.Carcharhiniformes.83.5
# CH.Rosales.nan
# MU.Crocodylia.nan
# MP.Serpentes.nan
# JP.Scrophulariales.18000.0
# MX.Sauria.nan
# DZ.Serpentes.nan
# AR.Scleractinia.19.193877551020407
# MY.Caryophyllales.nan
# TZ.Proboscidea.nan
# TR.Lepidoptera.nan
# UY.Artiodactyla.nan
# CY.Crocodylia.1.0
# ES.Acipenseriformes.590.9591666666666
# TG.Sauria.nan
# CY.Euphorbiales.nan
# CR.Sauria.nan
# IN.Rosales.14218.5
# MN.Perissodactyla.4.0
# KG.Primates.nan
# SG.Asterales.nan
# DK.Artiodactyla.3.111111111111111
# GR.Scleractinia.306.0
# AT.Perciformes.108.0
# PA.Sauria.nan
# KE.Crocodylia.30.299
# HU.Artiodactyla.211.11111111111111
# JP.Euphorbiales.4029.3975206611567
# NZ.Cetacea.21.0
# MO.Acipenseriformes.2.784333333333333
# KY.Orchidales.nan
# AT.Sauria.660.8333333333334
# SA.Rodentia.nan
# ME.Cyatheales.nan
# MF.Crocodylia.nan
# HT.Crocodylia.nan
# BR.Falconiformes.nan
# IL.Anura.nan
# LB.Stylasterina.nan
# BA.Sauria.nan
# EC.Sapindales.nan
# TW.Rhamnales.nan
# MO.Sauria.23.06896551724138
# SG.Stolonifera.35.0
# BS.Euphorbiales.nan
# MY.Gruiformes.nan
# DZ.Gruiformes.nan
# BM.Orchidales.nan
# NP.Falconiformes.nan
# AU.Crocodylia.nan
# IN.Sauria.10.0
# CN.Nepenthales.nan
# EE.Primates.nan
# BS.Fabales.nan
# ES.Proboscidea.4.416666666666667
# DE.Lamniformes.1.0
# CH.Arhynchobdellida.nan
# NZ.Perissodactyla.4.0
# NL.Rosales.nan
# MN.Acipenseriformes.nan
# XX.Crocodylia.nan
# IR.Artiodactyla.nan
# SR.Crocodylia.nan
# NL.Acipenseriformes.176.98008000000002
# CN.Chiroptera.nan
# CH.Proboscidea.nan
# HK.Aspidochirotida.8050.0
# MY.Apiales.250.0
# CN.Psittaciformes.115.3076923076923
# AD.Sauria.nan
# TR.Fabales.986.7066666666666
# PE.Lamniformes.18.0
# DE.Bromeliales.1180.0
# IM.Primates.2.0
# BY.Euphorbiales.nan
# NZ.Cuculiformes.1.0
# LK.Acipenseriformes.nan
# BH.Sauria.nan
# PY.Crocodylia.nan
# NP.Rodentia.nan
# US.Monotremata.2.0
# TL.Crocodylia.nan
# LK.Liliales.nan
# TW.Galliformes.nan
# SG.Scleractinia.513.2215568862275
# VN.Serpentes.nan
# GI.Nepenthales.nan
# DE.Euphorbiales.8850.597600000001
# GT.Primates.nan
# QA.Acipenseriformes.218.75
# MG.Rosales.104586.0
# HK.Arecales.2377.34
# FR.Veneroida.650.7333333333333
# NO.Caryophyllales.24.0
# HK.Anura.580.0
# BB.Cetacea.26.8
# ER.Crocodylia.nan
# DE.Selaginellales.2581.15
# AL.Liliales.nan
# BG.Psittaciformes.1.0
# JO.Piciformes.nan
# LB.Euphorbiales.nan
# HU.Carnivora.2.92
# JP.Columbiformes.1.0
# BB.Euphorbiales.nan
# IL.Serpentes.nan
# IN.Stolonifera.nan
# JP.Syngnathiformes.nan
# SK.Osteoglossiformes.15.0
# KZ.Psittaciformes.1.5555555555555556
# QA.Myrtales.nan
# MW.Serpentes.nan
# IN.Serpentes.29.5
# US.Asterales.266.73333333333335
# US.Cetacea.65.33366666666666
# AU.Chiroptera.nan
# IQ.Psittaciformes.100.0
# LU.Testudines.nan
# CH.Serpentes.nan
# TZ.Carnivora.nan
# SI.Perissodactyla.3.0
# CY.Galliformes.nan
# AZ.Crocodylia.nan
# IT.Carnivora.172.94285714285715
# JP.Rheiformes.1.0
# BH.Falconiformes.nan
# AR.Stylasterina.6.5
# XX.Fabales.nan
# TR.Stolonifera.70.0
# IR.Sapindales.nan
# KR.Primulales.nan
# TT.Caryophyllales.nan
# SG.Piciformes.31.0
# QA.Gruiformes.7.2
# AR.Proboscidea.12.0
# MY.Stylasterina.5.0
# NO.Milleporina.5.0
# PY.Sauria.nan
# IT.Testudines.5916.176470588235
# JE.Sauria.nan
# OM.Myrtales.nan
# LI.Sauria.nan
# OM.Liliales.nan
# RO.Acipenseriformes.4.224
# CH.Osteoglossiformes.nan
# HK.Primates.107.66666666666667
# ES.Strigiformes.550.0
# MM.Serpentes.nan
# VC.Orchidales.nan
# CN.Gorgonacea.1150.5400000000002
# RO.Primates.2.0
# PK.Columbiformes.nan
# HK.Stolonifera.85.2
# TR.Psittaciformes.533.3214285714286
# JO.Serpentes.nan
# TW.Anseriformes.nan
# PR.Serpentes.nan
# BD.Psittaciformes.nan
# MP.Crocodylia.nan
# NC.Acipenseriformes.nan
# SG.Anguilliformes.nan
# CA.Arecales.nan
# JP.Stolonifera.180.6
# AG.Liliales.nan
# ZA.Primates.nan
# CN.Proboscidea.18.457142857142856
# NZ.Sauria.2.2
# IN.Fabales.nan
# FR.Falconiformes.2.202
# MN.Carnivora.nan
# AR.Acipenseriformes.nan
# PL.Arhynchobdellida.11.0
# FI.Acipenseriformes.nan
# ID.Anura.nan
# TW.Euphorbiales.nan
# MC.Sauria.44.083333333333336
# JO.Proboscidea.nan
# AE.Stolonifera.nan
# PA.Cycadales.nan
# LU.Liliales.1110.0
# GB.Myrtales.10.0
# HK.Carnivora.135.33766666666668
# NZ.Acipenseriformes.0.7148533571428571
# HR.Testudines.1.5
# US.Pristiformes.3.8
# JP.Lamniformes.1.0
# GU.Sauria.nan
# CA.Anura.nan
# SR.Euphorbiales.nan
# HT.Serpentes.nan
# BS.Arecales.nan
# SY.Serpentes.nan
# MG.Crocodylia.5759.578947368421
# MM.Euphorbiales.nan
# IS.Acipenseriformes.nan
# DK.Anguilliformes.600.0
# CL.Caryophyllales.8070.0
# DK.Helioporacea.8.0
# CW.Primates.nan
# KH.Proboscidea.nan
# PK.Serpentes.nan
# ZA.Cetacea.nan
# KZ.Scleractinia.nan
# DO.Liliales.nan
# XV.Serpentes.nan
# IQ.Sauria.nan
# JP.Fagales.1295.2740000000001
# BR.Serpentes.nan
# JP.Cetacea.73.33333333333333
# HK.Carcharhiniformes.2423.170545454545
# BB.Caryophyllales.nan
# AU.Sauria.nan
# CN.Crocodylia.1533.5786030999998
# UZ.Sauria.nan
# PH.Euphorbiales.nan
# SK.Serpentes.18.90909090909091
# AT.Carnivora.3.0476190476190474
# ET.Apiales.nan
# JO.Orchidales.nan
# XV.Crocodylia.nan
# UZ.Psittaciformes.74.16666666666667
# GN.Serpentes.nan
# UZ.Crocodylia.nan
# BA.Proboscidea.nan
# BO.Crocodylia.nan
# RU.Crocodylia.nan
# MA.Cycadales.nan
# MX.Serpentes.nan
# MX.Sapindales.nan
# US.Piciformes.3.6
# CN.Pinales.631.75
# MY.Euphorbiales.2772.0
# UZ.Lepidoptera.120.0
# TW.Testudines.nan
# TH.Crocodylia.nan
# XX.Sauria.nan
# XX.Caryophyllales.nan
# CA.Euphorbiales.nan
# AE.Crocodylia.40.16
# SA.Passeriformes.nan
# CY.Orchidales.nan
# CO.Crocodylia.nan
# FR.Sapindales.9957.50675
# KH.Osteoglossiformes.nan
# IT.Perissodactyla.2.5
# FR.Gruiformes.2.0
# PK.Proboscidea.1.0
# HN.Liliales.nan
# MV.Liliales.nan
# EC.Orchidales.nan
# CH.Dipsacales.nan
# GU.Serpentes.nan
# AO.Gruiformes.nan
# SX.Orchidales.nan
# RE.Crocodylia.nan
# SG.Pinales.14459.3
# FR.Strigiformes.1.0
# US.Struthioniformes.1.6666666666666667
# SA.Nepenthales.nan
# GR.Carnivora.671.673125
# GP.Orchidales.nan
# TR.Sapindales.nan
# SG.Syngnathiformes.156.66666666666666
# SK.Anura.200.0
# SE.Crocodylia.116.7
# TM.Acipenseriformes.nan
# GR.Artiodactyla.nan
# TW.Proboscidea.nan
# LK.Orchidales.nan
# FR.Psittaciformes.2.021333333333333
# AU.Scrophulariales.nan
# OM.Proboscidea.nan
# DE.Scrophulariales.29678.2
# KP.Euphorbiales.nan
# ZW.Perissodactyla.nan
# TR.Pilosa.2.0
# JP.Strigiformes.11.259541984732824
# GB.Galliformes.1.4
# GD.Caryophyllales.nan
# JP.Veneroida.45.0
# MA.Serpentes.nan
# UA.Orchidales.nan
# GB.Arhynchobdellida.22.0
# NO.Stylasterina.4.0
# RU.Anseriformes.nan
# AU.Testudines.nan
# TH.Anguilliformes.nan
# DE.Nepenthales.30.5
# GG.Scleractinia.25.0
# PE.Crocodylia.11.5
# MA.Asterales.nan
# VN.Mesogastropoda.nan
# QA.Galliformes.30.857142857142858
# TR.Primates.261.7857142857143
# CN.Cycadales.261.0
# IE.Carnivora.1.0
# NG.Caryophyllales.nan
# IT.Proboscidea.44.57142857142857
# NZ.Dicksoniales.nan
# GF.Nepenthales.nan
# DE.Veneroida.549.2
# AL.Euphorbiales.nan
# FI.Fabales.nan
# FR.Primulales.96.66666666666667
# GF.Cycadales.nan
# GB.Osteoglossiformes.110.33333333333333
# RO.Psittaciformes.1.0
# FR.Milleporina.200.75
# TW.Bromeliales.nan
# FR.Lamniformes.2.0
# CW.Sauria.nan
# SX.Liliales.nan
# UA.Psittaciformes.nan
# TH.Asterales.nan
# IL.Caryophyllales.nan
# NP.Caryophyllales.nan
# TR.Nepenthales.nan
# CI.Liliales.nan
# JE.Coraciiformes.nan
# AL.Caryophyllales.nan
# NC.Carnivora.nan
# CA.Carnivora.nan
# GE.Nepenthales.nan
# US.Carnivora.418.44106457242583
# JO.Sauria.nan
# BH.Piciformes.nan
# SE.Psittaciformes.1.0
# MA.Myrtales.nan
# KW.Scleractinia.nan
# FR.Gentianales.600.0
# TN.Acipenseriformes.nan
# NE.Sauria.nan
# AU.Myrtales.nan
# HU.Crocodylia.150.0
# ES.Milleporina.7.0
# LR.Crocodylia.nan
# TW.Coraciiformes.nan
# TW.Carnivora.nan
# UZ.Primates.6.2727272727272725
# TR.Galliformes.4.0
# FR.Nepenthales.44.25818181818182
# CA.Gentianales.nan
# BB.Testudines.nan
# TR.Cetacea.3.5
# IS.Orchidales.nan
# AZ.Euphorbiales.nan
# PA.Testudines.nan
# LA.Serpentes.nan
# SE.Perissodactyla.6.75
# HK.Serpentes.660.9560439560439
# KR.Nepenthales.nan
# IR.Sauria.nan
# PT.Scleractinia.nan
# PT.Crocodylia.2130.2105263157896
# SG.Ciconiiformes.2.3333333333333335
# VE.Cetacea.4.0
# AR.Strigiformes.nan
# US.Gentianales.626.75
# CA.Crocodylia.nan
# PH.Psittaciformes.19.26865671641791
# OM.Psittaciformes.294.031007751938
# GT.Serpentes.nan
# BD.Sauria.nan
# MK.Crocodylia.nan
# AU.Artiodactyla.nan
# KP.Testudines.nan
# LB.Cycadales.nan
# MX.Proboscidea.nan
# NL.Apiales.nan
# IT.Antipatharia.nan
# MN.Orchidales.nan
# BN.Crocodylia.nan
# KZ.Gorgonacea.nan
# NZ.Fabales.nan
# AO.Acipenseriformes.nan
# TZ.Psittaciformes.nan
# NL.Stolonifera.117.0
# GL.Cetacea.nan
# GB.Araneae.200.0
# KE.Nepenthales.nan
# CH.Orchidales.nan
# BN.Psittaciformes.nan
# ID.Orchidales.nan
# CH.Gentianales.nan
# RS.Euphorbiales.25.0
# GB.Apiales.nan
# IT.Lepidoptera.20.0
# SG.Scrophulariales.nan
# AO.Psittaciformes.nan
# DE.Coraciiformes.1.5
# IT.Sauria.2745.6530612244896
# NO.Euphorbiales.13.0
# XX.Liliales.nan
# JP.Cyatheales.152.7378
# MD.Primates.nan
# TR.Falconiformes.3.0
# RW.Psittaciformes.1.0
# BB.Psittaciformes.9.473684210526315
# ME.Cycadales.nan
# GB.Crocodylia.462.5531914893617
# JE.Scleractinia.nan
# NL.Arecales.nan
# GI.Caryophyllales.nan
# ES.Dipsacales.nan
# BE.Sapindales.20.52
# IT.Gentianales.310.0
# KW.Piciformes.nan
# RS.Carnivora.1.0
# BD.Serpentes.nan
# ID.Strigiformes.nan
# TZ.Orchidales.nan
# RO.Crocodylia.109.66666666666667
# TR.Sauria.79.15151515151516
# ES.Diprotodontia.nan
# AM.Psittaciformes.nan
# ET.Sauria.nan
# MX.Orchidales.nan
# MY.Proboscidea.3.2504999999999997
# IQ.Orchidales.nan
# MY.Crocodylia.394.98924731182797
# PK.Scleractinia.nan
# KN.Sauria.nan
# KH.Myrtales.nan
# PL.Sirenia.2.0
# ZA.Apiales.nan
# TH.Sapindales.nan
# BE.Gentianales.1500.0
# HU.Gruiformes.1.0
# UA.Gruiformes.nan
# IL.Cuculiformes.nan
# MR.Serpentes.nan
# BL.Crocodylia.nan
# QA.Stolonifera.nan
# NL.Artiodactyla.7020.75
# CN.Helioporacea.11.0
# JP.Rhamnales.23.333333333333332
# KG.Falconiformes.nan
# TH.Cycadales.nan
# ID.Sauria.nan
# IQ.Crocodylia.nan
# BG.Primates.1.5
# SM.Carnivora.244.0
# JP.Serpentes.684.8430463576159
# CH.Galliformes.nan
# HK.Asterales.1036.15
# MY.Milleporina.2.0
# CH.Primates.nan
# CA.Caryophyllales.nan
# MC.Osteoglossiformes.3.0
# SI.Carnivora.1.0
# NO.Testudines.2.0
# XX.Cetacea.nan
# CN.Serpentes.1303.3346153846153
# RU.Primulales.nan
# PY.Stolonifera.nan
# US.Laurales.309.6666666666667
# PL.Archaeogastropoda.8564.0
# CR.Veneroida.nan
# BR.Stylasterina.nan
# FR.Scleractinia.915.9180327868852
# CL.Perissodactyla.nan
# ML.Sauria.nan
# US.Scleractinia.887.4492866082603
# CA.Perissodactyla.nan
# CZ.Cetacea.1.0
# KG.Caryophyllales.nan
# AE.Cycadales.30.0
# KZ.Orchidales.nan
# DK.Primates.465.2745945945946
# BR.Strigiformes.nan
# CW.Liliales.nan
# LT.Primates.1.0
# TH.Osteoglossiformes.nan
# HK.Pholidota.3264.0
# ML.Psittaciformes.nan
# RU.Liliales.nan
# IT.Nepenthales.nan
# VN.Caryophyllales.nan
# LI.Crocodylia.nan
# TW.Acipenseriformes.nan
# ES.Helioporacea.10.0
# AL.Serpentes.nan
# NL.Pinales.30000.0
# SK.Cetacea.nan
# KR.Stylasterina.nan
# FR.Dipsacales.5.0
# DE.Syngnathiformes.565.0
# RW.Perissodactyla.18.0
# IT.Psittaciformes.1.0
# AE.Testudines.74.5
# GB.Sphenisciformes.50.0
# MU.Primates.nan
# IL.Stylasterina.nan
# GB.Anura.64.125
# RE.Testudines.nan
# RU.Artiodactyla.nan
# GT.Orchidales.nan
# TW.Araneae.nan
# RU.Falconiformes.nan
# ES.Rhamnales.nan
# KR.Scrophulariales.nan
# TW.Dipsacales.nan
# XX.Nepenthales.nan
# AE.Proboscidea.nan
# SE.Lamniformes.116.0
# FJ.Orchidales.nan
# JP.Anguilliformes.1095153.5
# CH.Apiales.nan
# MT.Orchidales.11.79
# CZ.Primates.2.5833333333333335
# AU.Pristiformes.nan
# RO.Orchidales.1258.35
# AE.Fabales.nan
# AE.Myrtales.160039.83667741934
# LT.Proboscidea.4.0
# US.Cycadales.23178.60975609756
# CV.Orchidales.nan
# CZ.Perissodactyla.7.0
# TW.Falconiformes.nan
# EC.Strigiformes.nan
# ZA.Ranunculales.nan
# BM.Psittaciformes.nan
# JO.Acipenseriformes.nan
# PL.Psittaciformes.1.0
# CM.Perissodactyla.nan
# PK.Psittaciformes.nan
# HK.Violales.15.0
# DE.Primulales.13.0
# PL.Orchidales.62.8
# UZ.Scleractinia.200.0
# PG.Crocodylia.nan
# VN.Anseriformes.nan
# SG.Pholidota.1.0
# AR.Euphorbiales.550.0
# MX.Osteoglossiformes.nan
# MV.Cycadales.nan
# FR.Serpentes.1481.7787248322147
# SI.Orchidales.14840.0
# ES.Primulales.2462.5
# IT.Cyatheales.nan
# CA.Lepidoptera.nan
# NO.Nepenthales.nan
# CZ.Psittaciformes.4.538461538461538
# HK.Sauria.1317.9709302325582
# AE.Gruiformes.201.5
# DK.Myrtales.143700.0
# RO.Carnivora.3.2222222222222223
# GG.Proboscidea.nan
# BJ.Sauria.nan
# SG.Nepenthales.nan
# EC.Acipenseriformes.nan
# KW.Myrtales.613.3696666666667
# KR.Apiales.nan
# FR.Columbiformes.2.5
# AE.Sauria.20.615384615384617
# LV.Serpentes.2.0
# BN.Orchidales.nan
# KE.Primates.1.0
# XX.Myrtales.nan
# ES.Perissodactyla.8.467857142857143
# IT.Liliales.23686.666666666668
# PL.Lepidoptera.16.0
# RU.Helioporacea.nan
# GT.Passeriformes.nan
# CA.Proboscidea.nan
# CA.Galliformes.nan
# PK.Nepenthales.nan
# SG.Chiroptera.2801.6666666666665
# KP.Gruiformes.nan
# PE.Sapindales.25.0
# CA.Sapindales.nan
# BZ.Psittaciformes.nan
# BH.Carnivora.1.5
# TW.Stylasterina.nan
# JO.Falconiformes.nan
# TM.Orchidales.nan
# PA.Liliales.nan
# MO.Osteoglossiformes.nan
# EC.Falconiformes.nan
# RU.Cycadales.nan
# TW.Helioporacea.nan
# PK.Orchidales.nan
# AE.Falconiformes.43.958333333333336
# CA.Fabales.nan
# NZ.Primates.2.4444444444444446
# MV.Nepenthales.nan
# SV.Anura.200.0
# DK.Asterales.0.458
# NP.Cuculiformes.nan
# NL.Perissodactyla.nan
# TM.Sauria.nan
# FO.Nepenthales.nan
# TR.Violales.nan
# TC.Crocodylia.nan
# JP.Ranunculales.175.66666666666666
# SK.Falconiformes.1.5
# IN.Euphorbiales.nan
# AU.Nepenthales.nan
# YU.Artiodactyla.nan
# LI.Serpentes.nan
# JO.Stolonifera.nan
# BR.Osteoglossiformes.nan
# AT.Cetacea.3.2
# JP.Crocodylia.1230.1511780821918
# EG.Asterales.nan
# BE.Caryophyllales.200.0
# MU.Psittaciformes.nan
# IT.Myrtales.535.947
# CZ.Anura.111.25
# GA.Sauria.nan
# PE.Anseriformes.2.0
# US.Cyatheales.8756.333333333334
# SG.Myrtales.6945.883459459459
# SA.Asterales.nan
# BY.Sauria.nan
# GA.Crocodylia.nan
# GR.Nepenthales.1276.4041666666665
# GE.Primates.3.0
# EE.Acipenseriformes.69.0
# MA.Carnivora.1.0
# UA.Sapindales.nan
# ES.Arecales.20.0
# TN.Euphorbiales.nan
# FO.Testudines.nan
# CH.Bromeliales.nan
# GG.Araneae.1.0
# DE.Archaeogastropoda.1160.9
# CA.Gorgonacea.nan
# TH.Strigiformes.nan
# BH.Gruiformes.nan
# GQ.Serpentes.nan
# NL.Anura.42.206896551724135
# AR.Osteoglossiformes.nan
# KW.Sauria.1.0
# LK.Osteoglossiformes.nan
# GL.Sapindales.nan
# GP.Serpentes.nan
# RS.Liliales.nan
# MO.Serpentes.30.73170731707317
# CA.Testudines.nan
# PK.Dipsacales.nan
# DE.Anseriformes.2.0
# XX.Acipenseriformes.nan
# PL.Falconiformes.1.0
# QA.Orchidales.nan
# SA.Caryophyllales.nan
# AD.Proboscidea.nan
# IT.Helioporacea.nan
# BE.Primates.260.218637037037
# ML.Crocodylia.nan
# AO.Nepenthales.nan
# MA.Psittaciformes.nan
# FR.Gorgonacea.8.01516
# QA.Cycadales.nan
# DE.Fabales.2674.311625
# AE.Orchidales.6810.735294117647
# BE.Pinales.7500.0
# KR.Carcharhiniformes.nan
# OM.Carnivora.16.333333333333332
# BR.Perissodactyla.nan
# BM.Carnivora.nan
# US.Anseriformes.36967.5
# BN.Caryophyllales.nan
# GT.Testudines.nan
# JP.Myliobatiformes.11.333333333333334
# DE.Stylasterina.53.5
# IR.Scleractinia.nan
# ER.Serpentes.nan
# MA.Caryophyllales.nan
# MC.Artiodactyla.21.75
# BR.Cuculiformes.nan
# KP.Orchidales.nan
# UY.Serpentes.nan
# PE.Orchidales.nan
# MO.Liliales.nan
# NP.Carnivora.nan
# CH.Veneroida.nan
# IE.Proboscidea.1.0
# NL.Gentianales.nan
# BD.Asterales.nan
# ZA.Stylasterina.nan
# NZ.Testudines.1.3333333333333333
# TM.Primulales.nan
# GB.Apodiformes.nan
# VN.Fabales.nan
# BR.Primates.nan
# BB.Liliales.nan
# AZ.Testudines.nan
# PA.Carnivora.nan
# NL.Myrtales.15.669
# DO.Crocodylia.6.333333333333333
# KP.Strigiformes.nan
# TW.Milleporina.nan
# EG.Scleractinia.nan
# AR.Anseriformes.nan
# KP.Galliformes.nan
# GR.Stolonifera.nan
# IT.Serpentes.6791.41875
# MO.Cetacea.1.0
# SM.Stolonifera.109.0
# BR.Milleporina.nan
# IS.Artiodactyla.nan
# NZ.Cyatheales.8.0165
# KR.Myrtales.nan
# BE.Testudines.252.0
# IL.Gorgonacea.nan
# CR.Scleractinia.nan
# CN.Apiales.31841.51551666667
# IR.Orchidales.nan
# ZA.Testudines.nan
# UA.Primates.nan
# PL.Scrophulariales.19850.0
# IQ.Euphorbiales.nan
# MY.Orchidales.400.0
# JP.Carnivora.58.90188461538462
# BY.Nepenthales.nan
# CL.Veneroida.nan
# AU.Arecales.nan
# CH.Acipenseriformes.nan
# AU.Rosales.nan
# TW.Ranunculales.nan
# IS.Cetacea.nan
# IL.Anseriformes.nan
# BH.Liliales.nan
# PT.Nepenthales.nan
# MO.Myrtales.43.26666666666667
# IE.Milleporina.5.0
# AU.Caryophyllales.nan
# NZ.Psittaciformes.1.2352941176470589
# PT.Testudines.4911.5
# PA.Caryophyllales.nan
# FR.Euphorbiales.22825.859333333334
# GB.Artiodactyla.15.571428571428571
# BS.Cycadales.nan
# TJ.Psittaciformes.nan
# IQ.Nepenthales.nan
# BS.Sauria.nan
# BL.Sauria.nan
# JE.Serpentes.nan
# AU.Galliformes.nan
# KP.Osteoglossiformes.nan
# BG.Carnivora.1.2222222222222223
# NO.Osteoglossiformes.24.5
# SN.Caryophyllales.nan
# LB.Crocodylia.nan
# NG.Serpentes.nan
# AR.Caryophyllales.110560.0
# GG.Psittaciformes.1.0
# CY.Stylasterina.6.0
# JP.Sphenisciformes.nan
# PR.Crocodylia.nan
# CN.Laurales.nan
# NL.Orchidales.49134.22222222222
# SK.Nepenthales.nan
# GP.Sauria.nan
# ES.Galliformes.2616.6666666666665
# CA.Primates.nan
# IT.Perciformes.354.3333333333333
# RS.Sauria.nan
# PT.Sirenia.40.0
# KR.Arhynchobdellida.nan
# SG.Carnivora.171.0
# GG.Syngnathiformes.30.0
# AR.Rosales.50.5
# GR.Acipenseriformes.nan
# DK.Strigiformes.nan
# SG.Euphorbiales.nan
# AW.Orchidales.nan
# NO.Crocodylia.60.392857142857146
# RU.Primates.nan
# GB.Sauria.126.75555555555556
# UZ.Artiodactyla.1.3333333333333333
# CH.Struthioniformes.nan
# VN.Sapindales.nan
# CA.Caudata.nan
# MY.Perciformes.1.0
# MV.Lamniformes.nan
# RU.Proboscidea.nan
# IQ.Liliales.nan
# TR.Laurales.nan
# BM.Crocodylia.nan
# GB.Gentianales.5.0
# QA.Serpentes.68.44444444444444
# KZ.Euphorbiales.nan
# BY.Artiodactyla.3.5
# GT.Stolonifera.nan
# TN.Artiodactyla.7.5
# FR.Proboscidea.52.529259259259256
# IL.Falconiformes.nan
# JO.Stylasterina.nan
# US.Cuculiformes.22.25
# KN.Sapindales.nan
# UA.Anseriformes.nan
# KE.Orchidales.nan
# LU.Carnivora.1.0
# OM.Rodentia.12.0
# AT.Perissodactyla.16.454545454545453
# FI.Lepidoptera.nan
# DK.Crocodylia.84.43382352941177
# NZ.Carnivora.1.209025
# GE.Serpentes.3.0
# BQ.Liliales.nan
# CN.Columbiformes.4.0
# LB.Scleractinia.nan
# AT.Veneroida.nan
# LY.Piciformes.nan
# ME.Sauria.nan
# GB.Liliales.11391.0
# SA.Scleractinia.nan
# NZ.Ranunculales.150.0
# AD.Crocodylia.nan
# JE.Fabales.2.0
# KR.Euphorbiales.nan
# SX.Testudines.nan
# CL.Stolonifera.nan
# CO.Sapindales.nan
# GA.Acipenseriformes.nan
# JP.Gruiformes.nan
# KR.Sauria.nan
# AW.Passeriformes.nan
# US.Rodentia.8.2
# CA.Arhynchobdellida.nan
# IT.Cycadales.2984.2
# CH.Apodiformes.nan
# KZ.Ciconiiformes.2.0
# PL.Bromeliales.225.0
# JP.Scleractinia.589.2536585365854
# LT.Artiodactyla.1.0
# XX.Araneae.nan
# TN.Nepenthales.nan
# PH.Crocodylia.44.27777777777778
# BE.Osteoglossiformes.10.0
# DE.Sirenia.0.15000000000000002
# BG.Milleporina.nan
# IL.Piciformes.nan
# CN.Perissodactyla.4.96
# KZ.Liliales.nan
# QA.Carnivora.2.5
# BH.Stolonifera.nan
# GE.Crocodylia.nan
# TM.Psittaciformes.nan
# FR.Ranunculales.3103.6666666666665
# LV.Liliales.329.0
# NL.Lamniformes.nan
# SD.Caryophyllales.nan
# US.Helioporacea.766.5
# PL.Stolonifera.80.0
# LT.Crocodylia.37.8
# ZW.Proboscidea.nan
# GG.Veneroida.10.0
# VN.Artiodactyla.nan
# US.Euphorbiales.38037.2
# MY.Acipenseriformes.503368.5167647059
# KR.Fagales.nan
# LA.Crocodylia.nan
# ES.Mesogastropoda.nan
# CN.Cetacea.25.142857142857142
# SG.Sauria.8081.9
# ZW.Nepenthales.nan
# AE.Strigiformes.1.0
# MV.Sauria.nan
# CL.Acipenseriformes.nan
# AZ.Liliales.nan
# XX.Psittaciformes.nan
# MO.Proboscidea.21.0
# TH.Syngnathiformes.nan
# BE.Artiodactyla.8.263157894736842
# DE.Asterales.10188.992
# TR.Proboscidea.11.0
# AM.Liliales.nan
# BH.Proboscidea.nan
# MK.Liliales.nan
# XX.Gorgonacea.nan
# HR.Crocodylia.58.5
# SA.Stolonifera.nan
# PH.Osteoglossiformes.nan
# SN.Serpentes.nan
# PK.Gruiformes.nan
# HU.Ciconiiformes.1.0
# NP.Anseriformes.nan
# AW.Psittaciformes.nan
# AR.Serpentes.22.272727272727273
# JP.Gorgonacea.158.110895
# FR.Syngnathiformes.850.0
# LB.Liliales.nan
# DE.Strigiformes.1.3333333333333333
# AZ.Cycadales.nan
# BE.Scleractinia.97.73826373626375
# MW.Acipenseriformes.nan
# PL.Carnivora.6.391304347826087
# CH.Strigiformes.nan
# SZ.Primates.nan
# PT.Sauria.95.88888888888889
# NP.Rheiformes.nan
# QA.Passeriformes.3.0
# AU.Proboscidea.nan
# AU.Carnivora.nan
# IT.Mesogastropoda.nan
# CM.Acipenseriformes.nan
# PL.Primates.2.1666666666666665
# NP.Strigiformes.nan
# LB.Falconiformes.nan
# FR.Crocodylia.3298.255974025974
# SD.Psittaciformes.nan
# BE.Nepenthales.40.0
# TH.Primates.nan
# MD.Liliales.nan
# BW.Crocodylia.nan
# HK.Veneroida.221.22222222222223
# CZ.Proboscidea.5.666666666666667
# CH.Falconiformes.nan
# UY.Crocodylia.290.6
# UA.Nepenthales.nan
# FR.Anura.19.05
# IR.Helioporacea.nan
# AT.Orchidales.5.674418604651163
# DK.Proboscidea.3.0
# AZ.Carnivora.nan
# NZ.Galliformes.157.5
# FR.Fabales.2248.618777777778
# BR.Euphorbiales.nan
# AE.Mesogastropoda.2260.7
# RU.Lepidoptera.nan
# CH.Ciconiiformes.nan
# HK.Orchidales.58.13920319248826
# NI.Serpentes.nan
# GF.Euphorbiales.nan
# LB.Sauria.nan
# US.Aspidochirotida.25663.58
# HK.Liliales.668.27326
# NZ.Ciconiiformes.1.6666666666666667
# GB.Scrophulariales.250.0
# AR.Fabales.15.0
# BH.Cetacea.2.0
# GB.Laurales.180.0
# CL.Liliales.nan
# MX.Ciconiiformes.nan
# JP.Violales.60.8
# LB.Primates.nan
# CO.Fabales.nan
# AW.Sauria.nan
# KR.Caryophyllales.nan
# SM.Acipenseriformes.nan
# IT.Orchidales.46.111111111111114
# KZ.Falconiformes.5.181818181818182
# CH.Helioporacea.nan
# ZA.Sapindales.nan
# SG.Acipenseriformes.11961.00336764706
# IR.Stylasterina.nan
# SA.Cetacea.nan
# ID.Liliales.nan
# LK.Carnivora.nan
# CH.Syngnathiformes.nan
# ES.Gorgonacea.3.934
# CI.Sauria.nan
# IL.Veneroida.nan
# NO.Primates.19.0
# IE.Stolonifera.17.5
# UZ.Galliformes.8.0
# JP.Artiodactyla.4841.942860555556
# XV.Psittaciformes.nan
# SV.Sauria.6500.0
# CN.Osteoglossiformes.30778.833333333332
# MK.Orchidales.nan
# NO.Serpentes.57.892105263157895
# CZ.Pinales.nan
# HU.Orchidales.1156.5
# DK.Cuculiformes.1.0
# CA.Gruiformes.nan
# GB.Arecales.nan
# KR.Strigiformes.nan
# AZ.Falconiformes.nan
# AE.Liliales.45.333333333333336
# KR.Carnivora.nan
# DZ.Sauria.nan
# GH.Galliformes.nan
# ES.Ciconiiformes.3.0
# CL.Testudines.80.0
# IQ.Artiodactyla.nan
# IE.Psittaciformes.1.0
# PE.Serpentes.10.25
# ZW.Euphorbiales.nan
# CN.Lamiales.71967.50224999999
# SN.Primates.nan
# DE.Scleractinia.1231.08547008547
# HN.Crocodylia.nan
# TH.Rodentia.nan
# NL.Primulales.50721.57142857143
# KN.Cetacea.nan
# JP.Rosales.0.063
# CW.Mesogastropoda.nan
# SG.Fabales.1.5
# VA.Mesogastropoda.nan
# FO.Liliales.nan
# AR.Columbiformes.nan
# HK.Helioporacea.49.0
# NL.Cetacea.45.0
# MC.Testudines.1.0
# VG.Psittaciformes.nan
# UG.Scleractinia.1.0
# AU.Asterales.nan
# SM.Crocodylia.nan
# CN.Ciconiiformes.70.33333333333333
# TW.Laurales.nan
# PY.Fabales.nan
# DE.Lycopodiales.10000.0
# US.Ciconiiformes.1.25
# GG.Falconiformes.1.0
# BE.Proboscidea.2.195
# PL.Sauria.192.5
# NZ.Crocodylia.69.08108108108108
# RS.Caryophyllales.nan
# JP.Mesogastropoda.201.68555555555557
# NO.Myrtales.nan
# BA.Falconiformes.1.0
# SA.Columbiformes.nan
# ID.Euphorbiales.nan
# IL.Liliales.nan
# CH.Anura.nan
# KZ.Primulales.nan
# LU.Acipenseriformes.303.5366666666667
# HK.Myrtales.553.2756
# US.Apodiformes.13.214285714285714
# TR.Acipenseriformes.nan
# BZ.Crocodylia.nan
# UZ.Euphorbiales.nan
# AT.Sapindales.9596.476
# LY.Psittaciformes.nan
# PK.Artiodactyla.2.0
# MD.Euphorbiales.nan
# TH.Mesogastropoda.nan
# PF.Acipenseriformes.nan
# DE.Ericales.8058.333333333333
# MD.Psittaciformes.nan
# PY.Serpentes.nan
# SE.Cetacea.nan
# RO.Stolonifera.10.0
# IL.Testudines.nan
# KW.Caryophyllales.202.03174603174602
# DE.Cyatheales.4.0
# ZA.Psittaciformes.nan
# NC.Liliales.nan
# CW.Nepenthales.nan
# FI.Sauria.4.0
# JP.Psittaciformes.31.74774774774775
# DK.Perissodactyla.27.0
# LB.Proboscidea.nan
# NI.Crocodylia.nan
# KZ.Piciformes.1.5
# MC.Stolonifera.nan
# NL.Primates.167.68354864864864
# AT.Falconiformes.2.357142857142857
# GH.Testudines.nan
# BR.Myrtales.nan
# UZ.Caryophyllales.nan
# MC.Milleporina.5.0
# KR.Lamniformes.nan
# CL.Piciformes.4.0
# NO.Acipenseriformes.35.8656575
# CI.Orchidales.nan
# KZ.Gruiformes.393.5
# IQ.Falconiformes.nan
# AW.Crocodylia.nan
# TL.Sauria.nan
# CG.Orchidales.nan
# NP.Artiodactyla.nan
# JP.Asterales.8622.605714285713
# ZA.Proboscidea.nan
# NL.Caryophyllales.43805.71666666667
# KW.Perissodactyla.8.0
# DE.Arhynchobdellida.215.0
# FR.Rosales.178763.66666666666
# AW.Serpentes.nan
# TW.Anura.nan
# UZ.Proboscidea.2.0
# BD.Crocodylia.nan
# AM.Falconiformes.nan
# AE.Euphorbiales.8663.222222222223
# XV.Sauria.nan
# PL.Serpentes.83.2
# CH.Stolonifera.nan
# CH.Columbiformes.nan
# ES.Gentianales.19.333333333333332
# CR.Psittaciformes.nan
# LB.Serpentes.nan
# MC.Proboscidea.288.57142857142856
# AR.Primates.2.0
# QA.Ciconiiformes.3.0
# LU.Perissodactyla.nan
# TH.Veneroida.nan
# CD.Serpentes.nan
# NO.Cyatheales.nan
# AR.Sapindales.274.5785
# CZ.Orchidales.976.0487804878048
# RU.Myrtales.nan
# BE.Fabales.1320.0303333333334
# NO.Galliformes.149.0
# CD.Gruiformes.nan
# DE.Falconiformes.6.454545454545454
# RU.Galliformes.nan
# JP.Ceratodontiformes.22.0
# HU.Liliales.633075.0
# TN.Cycadales.nan
# OM.Crocodylia.nan
# RU.Psittaciformes.nan
# ES.Cycadales.3670.8
# GB.Ranunculales.nan
# ME.Acipenseriformes.nan
# MX.Laurales.nan
# AF.Bromeliales.3200.0
# ID.Crocodylia.nan
# BR.Crocodylia.nan
# AE.Asterales.nan
# XX.Milleporina.nan
# HK.Stylasterina.13.0
# DZ.Acipenseriformes.nan
# AZ.Caryophyllales.nan
# CN.Myrtales.3156.4376470588236
# DE.Perissodactyla.60.35294117647059
# MA.Columbiformes.nan
# CO.Ranunculales.nan
# US.Stylasterina.30.22222222222222
# RU.Sphenisciformes.nan
# JP.Arhynchobdellida.2750.0
# ZA.Myrtales.nan
# PK.Liliales.nan
# MX.Passeriformes.nan
# KE.Proboscidea.4.33
# MC.Scleractinia.19.666666666666668
# DK.Orchidales.11079.199999999999
# BB.Crocodylia.47.0
# IM.Carnivora.2.0
# PT.Orchidales.nan
# TR.Scleractinia.158.7159090909091
# GQ.Galliformes.nan
# CO.Orchidales.nan
# SN.Carcharhiniformes.nan
# GB.Columbiformes.1.0
# AN.Testudines.nan
# KE.Acipenseriformes.nan
# AO.Fabales.102.0
# AD.Artiodactyla.nan
# VG.Crocodylia.nan
# NG.Psittaciformes.nan
# AU.Passeriformes.nan
# PE.Euphorbiales.nan
# HT.Orchidales.nan
# TH.Fabales.nan
# AZ.Sauria.nan
# HK.Cycadales.10.0
# AR.Artiodactyla.3.0
# IT.Scrophulariales.20015.0
# HU.Scleractinia.nan
# KR.Pinales.nan
# AU.Apiales.nan
# SV.Orchidales.976.1
# PY.Falconiformes.nan
# IT.Fabales.78.639
# MY.Psittaciformes.47.833333333333336
# AR.Milleporina.10.0
# AZ.Proboscidea.nan
# GI.Testudines.nan
# KR.Arecales.nan
# PA.Acipenseriformes.nan
# UZ.Primulales.nan
# CO.Carnivora.nan
# UA.Gorgonacea.nan
# DE.Passeriformes.3.8333333333333335
# ID.Cetacea.nan
# KR.Piciformes.nan
# KR.Anguilliformes.nan
# BY.Cycadales.nan
# DE.Serpentes.3274.4848484848485
# VN.Sauria.nan
# TR.Sphenisciformes.11.0
# CN.Pilosa.2.0
# CA.Chiroptera.nan
# NO.Scleractinia.39.04255319148936
# OM.Caryophyllales.nan
# UZ.Falconiformes.330.5
# TJ.Carnivora.nan
# SE.Charadriiformes.nan
# US.Syngnathiformes.235.09677419354838
# SA.Carnivora.nan
# NC.Crocodylia.nan
# MY.Myrtales.625.92
# TM.Cycadales.nan
# IE.Perissodactyla.nan
# LT.Piciformes.1.0
# ...
# AU.Liliales.nan
# SZ.Asterales.nan
# KR.Orchidales.nan
# AE.Helioporacea.nan
# TH.Orchidales.nan
# XX.Mesogastropoda.nan
# MY.Anura.11.0
# FI.Psittaciformes.nan
# KY.Sauria.nan
# CL.Cuculiformes.2.7777777777777777
# NL.Sapindales.7601.0
# FR.Osteoglossiformes.6.0
# SG.Galliformes.nan
# IE.Scleractinia.53.516666666666666
# BS.Testudines.2.0
# BE.Crocodylia.10443.764705882353
# BA.Nepenthales.nan
# FR.Apiales.nan
# KR.Orectolobiformes.nan
# EE.Fabales.0.31
# DE.Apiales.69.964
# IE.Pinales.nan
# MY.Primates.2.5
# NI.Liliales.nan
# PF.Cetacea.nan
# CW.Orchidales.nan
# PY.Liliales.nan
# EC.Psittaciformes.nan
# MX.Psittaciformes.nan
# CZ.Artiodactyla.1.625
# SA.Fabales.nan
# KW.Liliales.90.61538461538461
# DZ.Liliales.nan
# IL.Passeriformes.nan
# MM.Crocodylia.nan
# SI.Crocodylia.265.8
# US.Perissodactyla.22.77777777777778
# BD.Falconiformes.nan
# KZ.Crocodylia.12.333333333333334
# BM.Acipenseriformes.nan
# MV.Crocodylia.nan
# SN.Helioporacea.nan
# KW.Orchidales.1515.1764705882354
# AU.Carcharhiniformes.nan
# SE.Helioporacea.nan
# NZ.Sapindales.nan
# CO.Proboscidea.nan
# FI.Proboscidea.1.0
# CH.Carnivora.nan
# KR.Gruiformes.nan
# CL.Anseriformes.nan
# SE.Scleractinia.59.89655172413793
# PY.Scleractinia.nan
# JP.Myrtales.558.2087928571428
# RS.Falconiformes.3.4545454545454546
# US.Artiodactyla.104.9073090909091
# TW.Veneroida.nan
# DE.Stolonifera.148.5
# DJ.Acipenseriformes.nan
# KR.Primates.nan
# RU.Fabales.nan
# CA.Myrtales.nan
# MV.Myrtales.nan
# BG.Acipenseriformes.18805.0
# LA.Acipenseriformes.nan
# IN.Cetacea.nan
# TR.Syngnathiformes.121.0
# BH.Psittaciformes.134.89719626168224
# US.Acipenseriformes.6066.007257383966
# NL.Bromeliales.64202.0
# GB.Mesogastropoda.2.5
# IN.Sapindales.nan
# FI.Orchidales.11284.2
# BE.Cetacea.3.5
# JP.Ciconiiformes.2.0
# LK.Serpentes.nan
# BF.Liliales.nan
# CL.Cyatheales.nan
# PH.Orchidales.nan
# CG.Acipenseriformes.nan
# AE.Artiodactyla.10.5
# IL.Euphorbiales.nan
# JM.Crocodylia.nan
# IL.Fabales.nan
# KP.Crocodylia.nan
# KR.Psittaciformes.nan
# KY.Crocodylia.nan
# PE.Testudines.339.0
# KZ.Sauria.2.5
# BS.Psittaciformes.1.5789473684210527
# VE.Perissodactyla.nan
# BE.Liliales.3.983745666666666
# LV.Primates.1.1666666666666667
# MY.Arhynchobdellida.6.5
# DE.Apodiformes.440.0
# AL.Sauria.nan
# FR.Arhynchobdellida.60120.0
# SN.Acipenseriformes.nan
# VN.Psittaciformes.nan
# GB.Myliobatiformes.25.0
# MF.Liliales.nan
# SE.Sauria.8.75
# PL.Proboscidea.3.8
# CD.Galliformes.nan
# AZ.Psittaciformes.nan
# FR.Cetacea.5.023571428571429
# KR.Sphenisciformes.nan
# SA.Crocodylia.nan
# BL.Orchidales.nan
# GU.Scleractinia.nan
# PL.Euphorbiales.nan
# ES.Passeriformes.nan
# HK.Gentianales.410.625
# UY.Carnivora.1.0
# PT.Psittaciformes.3.4285714285714284
# JO.Liliales.nan
# TN.Crocodylia.80029.75
# NZ.Antipatharia.nan
# SR.Osteoglossiformes.nan
# NG.Myrtales.nan
# BE.Cuculiformes.nan
# MD.Sauria.nan
# KH.Acipenseriformes.nan
# GB.Serpentes.148.6
# KW.Cyatheales.nan
# NZ.Euphorbiales.nan
# BR.Artiodactyla.nan
# PY.Primates.nan
# GR.Testudines.1.5
# ZA.Caryophyllales.nan
# TR.Myrtales.nan
# CU.Falconiformes.nan
# IT.Pinales.38155.5
# AT.Primates.5.625
# VN.Euphorbiales.nan
# BY.Orchidales.nan
# SG.Lepidoptera.150.0
# CL.Psittaciformes.10.214285714285714
# DE.Pholidota.2.0
# GR.Sauria.1500.0
# NL.Passeriformes.nan
# US.Crocodylia.787.5267765567767
# PH.Carnivora.6.0
# PA.Primates.nan
# BR.Helioporacea.nan
# US.Stolonifera.351.44444444444446
# MX.Scleractinia.nan
# AT.Helioporacea.30.0
# RU.Columbiformes.nan
# ZA.Lamniformes.nan
# GB.Strigiformes.4.0
# HU.Caryophyllales.nan
# NZ.Strigiformes.2.0
# JO.Crocodylia.nan
# SX.Nepenthales.nan
# EG.Proboscidea.nan
# HN.Acipenseriformes.nan
# VE.Sauria.nan
# DZ.Psittaciformes.nan
# BH.Mesogastropoda.nan
# KR.Ciconiiformes.nan
# MX.Primates.nan
# UY.Liliales.nan
# IN.Proboscidea.1.0
# JO.Milleporina.nan
# MT.Crocodylia.74.33333333333333
# HK.Laurales.1.0
# JP.Nepenthales.671.9102564102565
# JO.Apiales.nan
# IN.Myrtales.7904.42
# SN.Sauria.nan
# DE.Ciconiiformes.1.0
# GB.Euphorbiales.32011.323333333334
# MA.Crocodylia.1.0
# SG.Cycadales.nan
# QA.Cuculiformes.nan
# KY.Acipenseriformes.nan
# ZM.Artiodactyla.nan
# NO.Proboscidea.1.7777777777777777
# US.Proboscidea.48.50228310502283
# CA.Rosales.nan
# QA.Cyatheales.nan
# DZ.Crocodylia.nan
# TG.Serpentes.nan
# IL.Crocodylia.nan
# MG.Primates.2.0
# BG.Sauria.1.0
# CD.Psittaciformes.nan
# FR.Stylasterina.140.5
# IL.Sapindales.nan
# CH.Myrtales.nan
# SX.Acipenseriformes.nan
# MX.Gorgonacea.nan
# CA.Stolonifera.nan
# OM.Galliformes.30.0
# XX.Osteoglossiformes.nan
# TW.Nepenthales.nan
# TF.Testudines.nan
# BY.Primulales.nan
# KZ.Primates.2.75
# CL.Serpentes.10.375
# NZ.Cycadales.41.23076923076923
# TR.Caryophyllales.nan
# CO.Serpentes.nan
# DM.Serpentes.nan
# IS.Caryophyllales.nan
# PK.Sauria.nan
# AU.Acipenseriformes.nan
# CN.Gruiformes.30.0
# MC.Carnivora.3.2
# PH.Artiodactyla.1.5
# ZW.Orchidales.nan
# ZA.Stolonifera.nan
# HU.Sauria.26.181818181818183
# NL.Anseriformes.30.0
# DZ.Scleractinia.nan
# CA.Columbiformes.nan
# TR.Rheiformes.8.0
# BG.Orchidales.3665.0
# SN.Antipatharia.nan
# OM.Acipenseriformes.570.4111111111112
# DE.Cuculiformes.2.5
# IN.Sphenisciformes.8.0
# DE.Osteoglossiformes.14.015
# CG.Sauria.nan
# HK.Crocodylia.2354.348084577114
# MD.Orchidales.nan
# KH.Orchidales.nan
# TW.Orchidales.nan
# AE.Passeriformes.50.0
# SK.Sauria.1.0
# BA.Caryophyllales.nan
# SE.Primates.58.816153846153846
# JP.Antipatharia.268.3333333333333
# TR.Veneroida.97.5
# CO.Artiodactyla.nan
# HR.Serpentes.nan
# DE.Orchidales.52.38136054421769
# GH.Caryophyllales.nan
# NO.Stolonifera.4.0
# US.Testudines.232.48090909090908
# CN.Pholidota.2250.0
# HK.Milleporina.19.666666666666668
# AF.Liliales.159800.0
# US.Psittaciformes.14.878787878787879
# TN.Serpentes.1363.4285714285713
# AO.Liliales.nan
# XX.Falconiformes.nan
# DE.Helioporacea.276.0
# AL.Psittaciformes.nan
# TW.Fabales.nan
# CZ.Perciformes.1595.0
# ME.Euphorbiales.nan
# IT.Crocodylia.1302.1992337164752
# AE.Sapindales.nan
# HN.Serpentes.nan
# MY.Anseriformes.nan
# RU.Serpentes.nan
# CG.Crocodylia.nan
# GR.Helioporacea.nan
# CN.Artiodactyla.106.724
# BY.Primates.6.0
# SG.Gruiformes.2.2857142857142856
# BR.Laurales.nan
# AZ.Serpentes.nan
# VG.Cycadales.nan
# SE.Nepenthales.nan
# OM.Araneae.nan
# TW.Primates.nan
# AZ.Primates.nan
# AU.Sapindales.nan
# CN.Caryophyllales.1015.0
# NO.Orchidales.13795.0
# IS.Serpentes.nan
# TG.Crocodylia.nan
# TW.Piciformes.nan
# CN.Liliales.nan
# OM.Artiodactyla.22.0
# DJ.Crocodylia.nan
# HK.Cyatheales.0.4575
# LB.Galliformes.nan
# BE.Dipsacales.150.0
# IR.Acipenseriformes.nan
# SN.Fabales.nan
# ET.Scleractinia.nan
# JE.Anura.nan
# MG.Cycadales.nan
# UY.Orchidales.nan
# CL.Galliformes.4.0
# ES.Anura.650.0
# IN.Artiodactyla.nan
# TH.Artiodactyla.nan
# YT.Liliales.nan
# HK.Mesogastropoda.1478.3755555555554
# NZ.Falconiformes.1.0
# IT.Scleractinia.416.33812949640287
# CI.Serpentes.nan
# LT.Serpentes.34.0
# NO.Strigiformes.1.0
# SA.Liliales.nan
# RU.Carnivora.nan
# KR.Struthioniformes.nan
# MY.Lepidoptera.nan
# AR.Sauria.82.2
# GF.Caryophyllales.nan
# US.Lepidoptera.709.2222222222222
# BN.Sauria.nan
# SN.Testudines.nan
# KY.Mesogastropoda.nan
# BR.Liliales.nan
# MA.Orchidales.nan
# GB.Perciformes.3060.8
# MA.Acipenseriformes.nan
# SN.Perissodactyla.nan
# AG.Crocodylia.nan
# TR.Euphorbiales.nan
# AR.Perissodactyla.2.5
# TW.Strigiformes.nan
# BG.Scleractinia.33.529411764705884
# GB.Ebenales.1.0
# DK.Stolonifera.57.0
# TR.Gentianales.nan
# BR.Sauria.nan
# KZ.Serpentes.21.666666666666668
# CA.Liliales.nan
# MU.Acipenseriformes.nan
# TT.Crocodylia.nan
# UG.Primates.21.0
# EG.Acipenseriformes.nan
# IR.Milleporina.nan
# DK.Veneroida.100.0
# RU.Milleporina.nan
# NZ.Lepidoptera.941.6666666666666
# MX.Ranunculales.nan
# TH.Apiales.nan
# TW.Myrtales.nan
# DE.Sapindales.1489.502181818182
# CA.Lamniformes.nan
# AI.Cycadales.nan
# SA.Psittaciformes.nan
# VE.Primates.nan
# GB.Chiroptera.nan
# DK.Stylasterina.62.0
# MF.Orchidales.nan
# EG.Euphorbiales.nan
# VN.Primates.nan
# GB.Cycadales.100.0
# ES.Testudines.1579.357142857143
# FR.Helioporacea.30.0
# NL.Psittaciformes.2.0
# KR.Testudines.nan
# RU.Antipatharia.nan
# EG.Falconiformes.nan
# RO.Artiodactyla.1.6
# HU.Nepenthales.nan
# GB.Dipsacales.nan
# MO.Orchidales.5813.0
# CN.Acipenseriformes.27074.516968
# OM.Piciformes.33.0
# NP.Psittaciformes.nan
# JP.Laurales.63.86000000000001
# ET.Crocodylia.nan
# NO.Perissodactyla.9.0
# CL.Scleractinia.nan
# GE.Liliales.nan
# MM.Caryophyllales.nan
# PR.Sauria.nan
# DE.Milleporina.102.0
# PL.Caryophyllales.nan
# CN.Sapindales.106170.11644444446
# UG.Artiodactyla.nan
# CZ.Fabales.3.0
# BE.Veneroida.113.50116666666666
# XX.Proboscidea.nan
# LC.Mesogastropoda.5.77
# IT.Veneroida.1.0
# ES.Gruiformes.nan
# BA.Cyatheales.nan
# SG.Anseriformes.4.0
# GB.Veneroida.612.5
# FR.Asterales.5000.0
# VN.Testudines.nan
# LV.Psittaciformes.1.0
# BS.Sapindales.nan
# CA.Psittaciformes.nan
# RU.Sapindales.nan
# ES.Pinales.nan
# PE.Carnivora.1.5
# MY.Ciconiiformes.10.0
# BE.Orchidales.143.72235294117647
# CN.Piciformes.29.0
# MY.Liliales.nan
# DE.Testudines.1164.0196078431372
# GB.Gruiformes.nan
# XX.Primates.nan
# TW.Violales.nan
# CM.Sauria.nan
# BB.Serpentes.4.0
# CH.Artiodactyla.nan
# FR.Ciconiiformes.7.0
# NE.Serpentes.nan
# TH.Sauria.nan
# ID.Galliformes.nan
# TN.Caryophyllales.nan
# CN.Cyatheales.nan
# JE.Strigiformes.nan
# KR.Dipsacales.nan
# MD.Cycadales.nan
# FR.Carnivora.62.57524390243903
# TW.Serpentes.nan
# FR.Cycadales.134.16666666666666
# CA.Acipenseriformes.nan
# MC.Orchidales.nan
# ZA.Carcharhiniformes.nan
# GB.Nepenthales.447.0857142857143
# CA.Veneroida.nan
# AT.Psittaciformes.12.5
# SN.Ebenales.nan
# GE.Psittaciformes.2.1666666666666665
# MK.Serpentes.nan
# AT.Proboscidea.4.133333333333334
# ID.Sapindales.nan
# SA.Myrtales.nan
# IT.Sapindales.8.6815
# KY.Proboscidea.nan
# IR.Serpentes.nan
# KE.Caryophyllales.nan
# VN.Myrtales.nan
# SE.Proboscidea.2.1666666666666665
# BA.Liliales.nan
# GT.Liliales.nan
# MD.Caryophyllales.nan
# PE.Carcharhiniformes.6.333333333333333
# FR.Sirenia.1.5
# UA.Caryophyllales.nan
# BH.Scleractinia.nan
# KW.Carnivora.1.25
# US.Caryophyllales.29553.70491803279
# ES.Scrophulariales.840.0
# KR.Anura.nan
# PL.Helioporacea.38.0
# ES.Caryophyllales.4422.01
# KR.Sapindales.nan
# ZA.Falconiformes.nan
# TZ.Serpentes.nan
# SG.Proboscidea.10.272727272727273
# SG.Columbiformes.5.5
# JP.Proboscidea.37.642857142857146
# GP.Sapindales.nan
# CH.Gorgonacea.nan
# IN.Primates.1.0
# TW.Sauria.nan
# MX.Nepenthales.nan
# JE.Carnivora.nan
# KH.Serpentes.nan
# US.Galliformes.31970.921170212765
# US.Liliales.57749.517857142855
# DE.Artiodactyla.137.64666666666665
# IL.Psittaciformes.nan
# HK.Testudines.5657.1796875
# SI.Pinales.37.0
# JP.Bromeliales.23857.6
# HT.Psittaciformes.nan
# NZ.Caryophyllales.2000.0
# KW.Testudines.1.6666666666666667
# ME.Serpentes.nan
# NL.Syngnathiformes.314.1666666666667
# NG.Nepenthales.nan
# SA.Acipenseriformes.nan
# MC.Apodiformes.1.0
# NZ.Gruiformes.1.0
# CN.Sphenisciformes.6.111111111111111
# GD.Orchidales.nan
# BS.Caryophyllales.nan
# AZ.Nepenthales.nan
# US.Sirenia.36.0
# FR.Caryophyllales.250.5
# CL.Proboscidea.2.2
# DE.Rodentia.3.5
# TH.Myrtales.nan
# BL.Acipenseriformes.nan
# DE.Lepidoptera.109.29411764705883
# IT.Struthioniformes.1.0
# QA.Caryophyllales.nan
# UA.Carnivora.nan
# IE.Crocodylia.8.0
# ES.Primates.161.95045454545453
# KR.Falconiformes.nan
# CZ.Scleractinia.49.86046511627907
# SG.Passeriformes.4.0
# GB.Stylasterina.19.0
# CN.Veneroida.710.3333333333334
# CA.Stylasterina.nan
# KW.Falconiformes.1.0
# LC.Acipenseriformes.nan
# PH.Sauria.20.958333333333332
# MW.Psittaciformes.12.4
# CN.Mesogastropoda.nan
# MY.Veneroida.35.0
# CH.Milleporina.nan
# CN.Sauria.1061.3584905660377
# KW.Sapindales.nan
# TJ.Liliales.nan
# KR.Osteoglossiformes.nan
# MQ.Caryophyllales.nan
# FI.Perissodactyla.2.3333333333333335
# EG.Carnivora.nan
# CR.Orchidales.nan
# PL.Osteoglossiformes.120.0
# PT.Serpentes.273.22222222222223
# TM.Euphorbiales.nan
# BH.Passeriformes.3.0
# HR.Rosales.26.32
# SG.Gentianales.3120.0
# KW.Galliformes.12.0
# TR.Liliales.nan
# PL.Apodiformes.nan
# CZ.Falconiformes.2.0
# PH.Primates.nan
# IR.Passeriformes.nan
# BQ.Caryophyllales.nan
# GB.Stolonifera.347.5
# AU.Strigiformes.nan
# GN.Crocodylia.nan
# CZ.Sauria.137.25531914893617
# BB.Nepenthales.nan
# PL.Testudines.316.6666666666667
# ZA.Perissodactyla.nan
# NG.Proboscidea.nan
# BL.Scleractinia.nan
# QA.Proboscidea.nan
# TH.Liliales.nan
# GB.Perissodactyla.1.4
# DK.Serpentes.161.91666666666666
# AR.Gentianales.20.0
# MX.Anseriformes.nan
# VN.Cyatheales.nan
# DO.Psittaciformes.2.0
# MY.Osteoglossiformes.488.42857142857144
# GB.Syngnathiformes.253.0
# BM.Proboscidea.nan
# JP.Chiroptera.nan
# GB.Rheiformes.nan
# BH.Caryophyllales.nan
# SG.Serpentes.6931.608695652174
# RU.Sauria.nan
# MX.Anura.nan
# KG.Nepenthales.nan
# KZ.Artiodactyla.1.3333333333333333
# IL.Helioporacea.nan
# TR.Helioporacea.33.0
# KW.Stolonifera.nan
# AD.Carnivora.nan
# DE.Proboscidea.7.6875
# LB.Carnivora.nan
# HU.Primates.61.6
# SC.Acipenseriformes.nan
# CU.Proboscidea.18.194
# BR.Proboscidea.nan
# TT.Psittaciformes.3.142857142857143
# PE.Psittaciformes.1.0
# MX.Veneroida.nan
# JM.Psittaciformes.nan
# PF.Testudines.nan
# KG.Sauria.nan
# UA.Osteoglossiformes.nan
# AM.Caryophyllales.nan
# CO.Euphorbiales.nan
# AW.Nepenthales.nan
# TW.Mesogastropoda.nan
# GT.Artiodactyla.nan
# NG.Orchidales.nan
# MQ.Liliales.nan
# HU.Perissodactyla.14.25
# JP.Liliales.15421.859008
# NL.Perciformes.3.0
# ID.Osteoglossiformes.nan
# PH.Anura.6.6
# CD.Primates.nan
# BY.Crocodylia.nan
# US.Perciformes.35.666666666666664
# AT.Milleporina.nan
# IL.Milleporina.nan
# US.Orectolobiformes.6.0
# LU.Crocodylia.28.0
# UY.Perissodactyla.nan
# ZA.Osteoglossiformes.nan
# ET.Proboscidea.nan
# ZW.Psittaciformes.nan
# BB.Sapindales.nan
# CO.Liliales.nan
# LB.Orchidales.nan
# TN.Carnivora.2.0
# AU.Veneroida.nan
# IM.Serpentes.nan
# IT.Cetacea.10.0
# RU.Osteoglossiformes.nan
# ES.Violales.15.5
# BA.Perissodactyla.nan
# AO.Serpentes.nan
# DO.Orchidales.6384.04347826087
# SK.Rodentia.nan
# BE.Milleporina.3.0
# GT.Psittaciformes.nan
# JP.Passeriformes.37.666666666666664
# RE.Orchidales.nan
# PH.Sapindales.nan
# US.Diprotodontia.4.5
# IT.Apiales.15000.0
# MC.Anseriformes.2.0
# TH.Falconiformes.nan
# NP.Coraciiformes.nan
# US.Caudata.1.5
# BS.Veneroida.nan
# BM.Serpentes.nan
# AT.Crocodylia.1837.6666666666667
# MV.Euphorbiales.nan
# PK.Carnivora.1.0
# SE.Acipenseriformes.nan
# PL.Acipenseriformes.nan
# AD.Gorgonacea.nan
# LT.Carnivora.2.6153846153846154
# JP.Acipenseriformes.3472.7027487937244
# SG.Caryophyllales.540.0
# HK.Scleractinia.248.37222222222223
# PH.Testudines.33.25
# VI.Crocodylia.nan
# QA.Rheiformes.6.0
# JO.Carnivora.nan
# AO.Sauria.nan
# HK.Gorgonacea.10.011708333333333
# DK.Nepenthales.nan
# NL.Scleractinia.655.8163265306123
# US.Dipsacales.60.0
# BD.Galliformes.nan
# GY.Crocodylia.nan
# XX.Anura.nan
# CY.Acipenseriformes.nan
# CA.Cuculiformes.nan
# ZA.Acipenseriformes.nan
# TT.Serpentes.2.0
# AT.Artiodactyla.4.555555555555555
# IN.Gentianales.20.0
# NL.Coraciiformes.1.0
# MK.Lepidoptera.nan
# BQ.Orchidales.nan
# NZ.Mesogastropoda.0.8
# MY.Stolonifera.52.5
# SE.Syngnathiformes.49.0
# CY.Liliales.nan
# RU.Gorgonacea.nan
# BN.Nepenthales.nan
# HU.Psittaciformes.1.0
# NZ.Milleporina.254.5
# DE.Psittaciformes.21.4
# AE.Apiales.nan
# AL.Acipenseriformes.nan
# AE.Rheiformes.12.0
# TN.Anseriformes.nan
# FR.Sauria.474.6165306122449
# BH.Artiodactyla.nan
# HK.Syngnathiformes.98.25
# IR.Euphorbiales.nan
# TJ.Primates.nan
# FR.Apodiformes.nan
# CH.Asterales.nan
# HK.Nepenthales.225.66666666666666
# ES.Artiodactyla.6.805249999999999
# CZ.Gentianales.100.0
# MQ.Serpentes.nan
# US.Ceratodontiformes.1.0
# CL.Passeriformes.10.0
# PL.Cycadales.1.0
# MY.Sauria.90.10169491525424
# GI.Orchidales.nan
# HU.Anura.41.0
# PK.Primates.nan
# ZA.Sauria.nan
# JO.Artiodactyla.nan
# CO.Psittaciformes.nan
# KZ.Perissodactyla.2.0
# VG.Acipenseriformes.nan
# KZ.Anseriformes.nan
# NG.Crocodylia.nan
# ZM.Primates.nan
# VN.Perissodactyla.nan
# ZA.Nepenthales.nan
# ZA.Crocodylia.nan
# ZW.Crocodylia.4.0
# TT.Scleractinia.nan
# AE.Galliformes.11.0
# SG.Cetacea.2.0
# HK.Cetacea.4.0
# ID.Artiodactyla.nan
# KR.Lamiales.nan
# MO.Testudines.20.0
# VN.Crocodylia.nan
# IQ.Myrtales.nan
# MD.Acipenseriformes.nan
# UA.Cyatheales.nan
# BR.Cyatheales.nan
# TW.Liliales.nan
# PT.Passeriformes.11.0
# AE.Gorgonacea.nan
# PE.Nepenthales.nan
# EG.Primates.nan
# BY.Serpentes.nan
# AZ.Artiodactyla.nan
# TH.Rhamnales.nan
# DO.Acipenseriformes.nan
# CH.Chiroptera.nan
# IL.Stolonifera.nan
# AL.Crocodylia.nan
# QA.Mesogastropoda.nan
# AZ.Acipenseriformes.nan
# MM.Liliales.nan
# GE.Piciformes.nan
# DO.Sapindales.794.1895833333333
# TW.Osteoglossiformes.nan
# MV.Acipenseriformes.nan
# CR.Stolonifera.nan
# BG.Helioporacea.nan
# AT.Scleractinia.124.03260869565217
# MA.Primates.4.0
# PA.Nepenthales.nan
# DO.Caryophyllales.nan
# JE.Primates.2.0
# KW.Gruiformes.nan
# UY.Psittaciformes.1.0
# US.Arecales.150.0
# ID.Serpentes.nan
# TR.Serpentes.192.23270270270268
# BR.Carnivora.nan
# NL.Ciconiiformes.12.0
# CA.Strigiformes.nan
# LB.Sapindales.nan
# TH.Scleractinia.nan
# GB.Coraciiformes.2.0
# KG.Orchidales.nan
# CH.Psittaciformes.nan
# RU.Testudines.nan
# ES.Osteoglossiformes.77.0
# ES.Orchidales.30.0
# TW.Sapindales.nan
# UA.Galliformes.nan
# IL.Cyatheales.nan
# PH.Nepenthales.nan
# AR.Passeriformes.nan
# GB.Sapindales.411.825
# FR.Pinales.nan
# BR.Acipenseriformes.nan
# IN.Caryophyllales.4600.0
# AT.Testudines.4.0
# Running time to load and process: 42.36 seconds

# %%
import pandas as pd
import redis
import time

# Connect to Redis
REDIS_SERVER = '35.202.201.207'
REDIS_PORT   = 6379
myRedis = redis.StrictRedis(host=REDIS_SERVER, port=REDIS_PORT, db=0)
df=pd.read_csv('comptab_2018-01-29 16_00_comma_separated.csv')
f=df.groupby(['Importer','Order'])['Importer reported quantity'].mean()
n = 10
start_time = time.time()
for i in range(n):
#Loading into Redis
    for key, value in f.items():
        hash_field = f"{key[0]}.{key[1]}"
        myRedis.hset("animalsperorder", hash_field, value)
#Retrieving rows from Redis
    values=myRedis.hgetall("animalsperorder")
end_time = time.time()
avg_time = (end_time - start_time) / n
print(f"Average time to load and process: {avg_time:.2f} seconds")
# Out:
# Average time to load and process: 42.34 seconds

# %% [markdown]
# <div style="font-size:20px;background-color:#BE6D00;color:#F6EFE5;padding:10px;text-align:center;">
# STOP YOUR CLUSTER WHEN YOU ARE NOT WORKING<br><br>
# ONCE YOU ARE FINISHED, DELETE YOUR CLUSTER
# </div>
# <br>
